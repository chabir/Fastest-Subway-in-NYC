# %%
from google.transit import gtfs_realtime_pb2
import urllib
import time
import datetime

from bs4 import BeautifulSoup
import requests
import re

# %%
## pulling info from api

feed = gtfs_realtime_pb2.FeedMessage()
response = urllib.urlopen('http://datamine.mta.info/mta_esi.php?key=5a8f6f4375e9f4bdea9b0c86afeaf911')
feed.ParseFromString(response.read())
for entity in feed.entity:
  if entity.HasField('trip_update'):
    print entity.trip_update
# Out:
# trip {
#   trip_id: "104700_1..N"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602545
#   }
#   departure {
#     time: 1437602545
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602875
#   }
#   departure {
#     time: 1437602875
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602965
#   }
#   departure {
#     time: 1437602965
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603055
#   }
#   departure {
#     time: 1437603055
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603115
#   }
#   departure {
#     time: 1437603115
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603235
#   }
#   departure {
#     time: 1437603235
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603355
#   }
#   departure {
#     time: 1437603355
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603445
#   }
#   departure {
#     time: 1437603445
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603565
#   }
#   departure {
#     time: 1437603565
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603655
#   }
#   departure {
#     time: 1437603655
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603775
#   }
#   departure {
#     time: 1437603775
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603865
#   }
#   departure {
#     time: 1437603865
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603955
#   }
#   departure {
#     time: 1437603955
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604045
#   }
#   departure {
#     time: 1437604045
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604135
#   }
#   departure {
#     time: 1437604135
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604255
#   }
#   departure {
#     time: 1437604255
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604345
#   }
#   departure {
#     time: 1437604345
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604435
#   }
#   departure {
#     time: 1437604435
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604525
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "102100_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602638
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "102300_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602657
#   }
#   departure {
#     time: 1437602657
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602747
#   }
#   departure {
#     time: 1437602747
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602837
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "102600_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602623
#   }
#   departure {
#     time: 1437602743
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602893
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "102700_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602677
#   }
#   departure {
#     time: 1437602677
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602767
#   }
#   departure {
#     time: 1437602767
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602857
#   }
#   departure {
#     time: 1437602887
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602977
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "103000_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602691
#   }
#   departure {
#     time: 1437602691
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602781
#   }
#   departure {
#     time: 1437602901
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603051
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "103100_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602704
#   }
#   departure {
#     time: 1437602704
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602794
#   }
#   departure {
#     time: 1437602794
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602884
#   }
#   departure {
#     time: 1437602884
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602974
#   }
#   departure {
#     time: 1437602974
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603064
#   }
#   departure {
#     time: 1437603064
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603154
#   }
#   departure {
#     time: 1437603214
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603304
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "103500_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602691
#   }
#   departure {
#     time: 1437602691
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602811
#   }
#   departure {
#     time: 1437602811
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602901
#   }
#   departure {
#     time: 1437602901
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602991
#   }
#   departure {
#     time: 1437602991
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603081
#   }
#   departure {
#     time: 1437603081
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603171
#   }
#   departure {
#     time: 1437603171
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603261
#   }
#   departure {
#     time: 1437603261
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603351
#   }
#   departure {
#     time: 1437603351
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603441
#   }
#   departure {
#     time: 1437603441
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603531
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "103550_1..S07R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602738
#   }
#   departure {
#     time: 1437602858
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602948
#   }
#   departure {
#     time: 1437602948
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603038
#   }
#   departure {
#     time: 1437603158
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603308
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "103800_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602668
#   }
#   departure {
#     time: 1437602668
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602758
#   }
#   departure {
#     time: 1437602758
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602848
#   }
#   departure {
#     time: 1437602848
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602938
#   }
#   departure {
#     time: 1437602938
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602998
#   }
#   departure {
#     time: 1437602998
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603088
#   }
#   departure {
#     time: 1437603208
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603298
#   }
#   departure {
#     time: 1437603298
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603388
#   }
#   departure {
#     time: 1437603508
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603658
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "103900_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602772
#   }
#   departure {
#     time: 1437602772
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602892
#   }
#   departure {
#     time: 1437602892
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602982
#   }
#   departure {
#     time: 1437602982
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603102
#   }
#   departure {
#     time: 1437603102
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603192
#   }
#   departure {
#     time: 1437603192
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603312
#   }
#   departure {
#     time: 1437603312
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603402
#   }
#   departure {
#     time: 1437603402
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603492
#   }
#   departure {
#     time: 1437603492
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603582
#   }
#   departure {
#     time: 1437603582
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603672
#   }
#   departure {
#     time: 1437603672
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603762
#   }
#   departure {
#     time: 1437603762
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603852
#   }
#   departure {
#     time: 1437603852
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603942
#   }
#   departure {
#     time: 1437603942
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604032
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "104200_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602745
#   }
#   departure {
#     time: 1437602745
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602805
#   }
#   departure {
#     time: 1437602805
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602865
#   }
#   departure {
#     time: 1437602865
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602925
#   }
#   departure {
#     time: 1437602925
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603015
#   }
#   departure {
#     time: 1437603015
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603105
#   }
#   departure {
#     time: 1437603105
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603195
#   }
#   departure {
#     time: 1437603195
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603255
#   }
#   departure {
#     time: 1437603255
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603345
#   }
#   departure {
#     time: 1437603465
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603555
#   }
#   departure {
#     time: 1437603555
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603645
#   }
#   departure {
#     time: 1437603765
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603915
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "104600_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602691
#   }
#   departure {
#     time: 1437602691
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602811
#   }
#   departure {
#     time: 1437602811
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602931
#   }
#   departure {
#     time: 1437602931
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603021
#   }
#   departure {
#     time: 1437603021
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603111
#   }
#   departure {
#     time: 1437603111
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603171
#   }
#   departure {
#     time: 1437603171
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603231
#   }
#   departure {
#     time: 1437603231
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603291
#   }
#   departure {
#     time: 1437603291
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603381
#   }
#   departure {
#     time: 1437603381
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603471
#   }
#   departure {
#     time: 1437603471
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603561
#   }
#   departure {
#     time: 1437603561
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603621
#   }
#   departure {
#     time: 1437603621
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603711
#   }
#   departure {
#     time: 1437603831
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603921
#   }
#   departure {
#     time: 1437603921
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604011
#   }
#   departure {
#     time: 1437604161
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604311
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "105050_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602749
#   }
#   departure {
#     time: 1437602749
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602839
#   }
#   departure {
#     time: 1437602839
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602929
#   }
#   departure {
#     time: 1437602929
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603049
#   }
#   departure {
#     time: 1437603049
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603169
#   }
#   departure {
#     time: 1437603169
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603259
#   }
#   departure {
#     time: 1437603259
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603349
#   }
#   departure {
#     time: 1437603349
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603409
#   }
#   departure {
#     time: 1437603409
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603469
#   }
#   departure {
#     time: 1437603469
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603529
#   }
#   departure {
#     time: 1437603529
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603619
#   }
#   departure {
#     time: 1437603619
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603709
#   }
#   departure {
#     time: 1437603709
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603799
#   }
#   departure {
#     time: 1437603799
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603859
#   }
#   departure {
#     time: 1437603859
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603949
#   }
#   departure {
#     time: 1437604069
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604159
#   }
#   departure {
#     time: 1437604159
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604249
#   }
#   departure {
#     time: 1437604429
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604579
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "105100_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602673
#   }
#   departure {
#     time: 1437602673
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602793
#   }
#   departure {
#     time: 1437602793
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602883
#   }
#   departure {
#     time: 1437602883
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603003
#   }
#   departure {
#     time: 1437603003
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603093
#   }
#   departure {
#     time: 1437603093
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603183
#   }
#   departure {
#     time: 1437603183
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603243
#   }
#   departure {
#     time: 1437603243
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603363
#   }
#   departure {
#     time: 1437603363
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603483
#   }
#   departure {
#     time: 1437603483
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603573
#   }
#   departure {
#     time: 1437603573
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603693
#   }
#   departure {
#     time: 1437603693
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603783
#   }
#   departure {
#     time: 1437603783
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603903
#   }
#   departure {
#     time: 1437603903
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603993
#   }
#   departure {
#     time: 1437603993
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604083
#   }
#   departure {
#     time: 1437604083
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604173
#   }
#   departure {
#     time: 1437604173
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604263
#   }
#   departure {
#     time: 1437604263
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604383
#   }
#   departure {
#     time: 1437604383
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604473
#   }
#   departure {
#     time: 1437604473
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604563
#   }
#   departure {
#     time: 1437604563
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604653
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "105500_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602665
#   }
#   departure {
#     time: 1437602665
#   }
#   stop_id: "124N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602755
#   }
#   departure {
#     time: 1437602755
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602875
#   }
#   departure {
#     time: 1437602875
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602965
#   }
#   departure {
#     time: 1437602965
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603085
#   }
#   departure {
#     time: 1437603085
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603175
#   }
#   departure {
#     time: 1437603175
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603265
#   }
#   departure {
#     time: 1437603265
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603325
#   }
#   departure {
#     time: 1437603325
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603445
#   }
#   departure {
#     time: 1437603445
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603565
#   }
#   departure {
#     time: 1437603565
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603655
#   }
#   departure {
#     time: 1437603655
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603775
#   }
#   departure {
#     time: 1437603775
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603865
#   }
#   departure {
#     time: 1437603865
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603985
#   }
#   departure {
#     time: 1437603985
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604075
#   }
#   departure {
#     time: 1437604075
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604165
#   }
#   departure {
#     time: 1437604165
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604255
#   }
#   departure {
#     time: 1437604255
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604345
#   }
#   departure {
#     time: 1437604345
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604465
#   }
#   departure {
#     time: 1437604465
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604555
#   }
#   departure {
#     time: 1437604555
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604645
#   }
#   departure {
#     time: 1437604705
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604795
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "105550_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602561
#   }
#   departure {
#     time: 1437602561
#   }
#   stop_id: "120S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602681
#   }
#   departure {
#     time: 1437602681
#   }
#   stop_id: "121S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602741
#   }
#   departure {
#     time: 1437602741
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602831
#   }
#   departure {
#     time: 1437602831
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602921
#   }
#   departure {
#     time: 1437602921
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603011
#   }
#   departure {
#     time: 1437603011
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603131
#   }
#   departure {
#     time: 1437603131
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603251
#   }
#   departure {
#     time: 1437603251
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603341
#   }
#   departure {
#     time: 1437603341
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603431
#   }
#   departure {
#     time: 1437603431
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603491
#   }
#   departure {
#     time: 1437603491
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603551
#   }
#   departure {
#     time: 1437603551
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603611
#   }
#   departure {
#     time: 1437603611
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603701
#   }
#   departure {
#     time: 1437603701
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603791
#   }
#   departure {
#     time: 1437603791
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603881
#   }
#   departure {
#     time: 1437603881
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603941
#   }
#   departure {
#     time: 1437603941
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604031
#   }
#   departure {
#     time: 1437604151
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604241
#   }
#   departure {
#     time: 1437604241
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604331
#   }
#   departure {
#     time: 1437604511
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604661
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "105900_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602670
#   }
#   departure {
#     time: 1437602670
#   }
#   stop_id: "125N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602760
#   }
#   departure {
#     time: 1437602760
#   }
#   stop_id: "124N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602850
#   }
#   departure {
#     time: 1437602850
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602970
#   }
#   departure {
#     time: 1437602970
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603060
#   }
#   departure {
#     time: 1437603060
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603180
#   }
#   departure {
#     time: 1437603180
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603270
#   }
#   departure {
#     time: 1437603270
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603360
#   }
#   departure {
#     time: 1437603360
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603420
#   }
#   departure {
#     time: 1437603420
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603540
#   }
#   departure {
#     time: 1437603540
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603660
#   }
#   departure {
#     time: 1437603660
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603750
#   }
#   departure {
#     time: 1437603750
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603870
#   }
#   departure {
#     time: 1437603870
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603960
#   }
#   departure {
#     time: 1437603960
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604080
#   }
#   departure {
#     time: 1437604080
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604170
#   }
#   departure {
#     time: 1437604170
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604260
#   }
#   departure {
#     time: 1437604260
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604350
#   }
#   departure {
#     time: 1437604350
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604440
#   }
#   departure {
#     time: 1437604440
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604560
#   }
#   departure {
#     time: 1437604560
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604650
#   }
#   departure {
#     time: 1437604650
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604740
#   }
#   departure {
#     time: 1437604740
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604830
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "106300_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602774
#   }
#   departure {
#     time: 1437602774
#   }
#   stop_id: "126N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602924
#   }
#   departure {
#     time: 1437602924
#   }
#   stop_id: "125N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603014
#   }
#   departure {
#     time: 1437603014
#   }
#   stop_id: "124N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603104
#   }
#   departure {
#     time: 1437603104
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603224
#   }
#   departure {
#     time: 1437603224
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603314
#   }
#   departure {
#     time: 1437603314
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603434
#   }
#   departure {
#     time: 1437603434
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603524
#   }
#   departure {
#     time: 1437603524
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603614
#   }
#   departure {
#     time: 1437603614
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603674
#   }
#   departure {
#     time: 1437603674
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603794
#   }
#   departure {
#     time: 1437603794
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603914
#   }
#   departure {
#     time: 1437603914
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604004
#   }
#   departure {
#     time: 1437604004
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604124
#   }
#   departure {
#     time: 1437604124
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604214
#   }
#   departure {
#     time: 1437604214
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604334
#   }
#   departure {
#     time: 1437604334
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604424
#   }
#   departure {
#     time: 1437604424
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604514
#   }
#   departure {
#     time: 1437604514
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604604
#   }
#   departure {
#     time: 1437604604
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604694
#   }
#   departure {
#     time: 1437604694
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604814
#   }
#   departure {
#     time: 1437604814
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604904
#   }
#   departure {
#     time: 1437604904
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604994
#   }
#   departure {
#     time: 1437604994
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605084
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "106550_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602755
#   }
#   departure {
#     time: 1437602755
#   }
#   stop_id: "114S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602845
#   }
#   departure {
#     time: 1437602845
#   }
#   stop_id: "115S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602935
#   }
#   departure {
#     time: 1437602935
#   }
#   stop_id: "116S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603085
#   }
#   departure {
#     time: 1437603085
#   }
#   stop_id: "117S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603145
#   }
#   departure {
#     time: 1437603145
#   }
#   stop_id: "118S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603205
#   }
#   departure {
#     time: 1437603205
#   }
#   stop_id: "119S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603325
#   }
#   departure {
#     time: 1437603325
#   }
#   stop_id: "120S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603445
#   }
#   departure {
#     time: 1437603445
#   }
#   stop_id: "121S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603505
#   }
#   departure {
#     time: 1437603505
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603595
#   }
#   departure {
#     time: 1437603595
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603685
#   }
#   departure {
#     time: 1437603685
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603775
#   }
#   departure {
#     time: 1437603775
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603895
#   }
#   departure {
#     time: 1437603895
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604015
#   }
#   departure {
#     time: 1437604015
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604105
#   }
#   departure {
#     time: 1437604105
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604195
#   }
#   departure {
#     time: 1437604195
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604255
#   }
#   departure {
#     time: 1437604255
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604315
#   }
#   departure {
#     time: 1437604315
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604375
#   }
#   departure {
#     time: 1437604375
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604465
#   }
#   departure {
#     time: 1437604465
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604555
#   }
#   departure {
#     time: 1437604555
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604645
#   }
#   departure {
#     time: 1437604645
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604705
#   }
#   departure {
#     time: 1437604705
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604795
#   }
#   departure {
#     time: 1437604915
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605005
#   }
#   departure {
#     time: 1437605005
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605095
#   }
#   departure {
#     time: 1437605275
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605425
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "106700_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602752
#   }
#   departure {
#     time: 1437602752
#   }
#   stop_id: "129N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602812
#   }
#   departure {
#     time: 1437602812
#   }
#   stop_id: "128N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602932
#   }
#   departure {
#     time: 1437602932
#   }
#   stop_id: "127N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603052
#   }
#   departure {
#     time: 1437603052
#   }
#   stop_id: "126N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603202
#   }
#   departure {
#     time: 1437603202
#   }
#   stop_id: "125N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603292
#   }
#   departure {
#     time: 1437603292
#   }
#   stop_id: "124N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603382
#   }
#   departure {
#     time: 1437603382
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603502
#   }
#   departure {
#     time: 1437603502
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603592
#   }
#   departure {
#     time: 1437603592
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603712
#   }
#   departure {
#     time: 1437603712
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603802
#   }
#   departure {
#     time: 1437603802
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603892
#   }
#   departure {
#     time: 1437603892
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603952
#   }
#   departure {
#     time: 1437603952
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604072
#   }
#   departure {
#     time: 1437604072
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604192
#   }
#   departure {
#     time: 1437604192
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604282
#   }
#   departure {
#     time: 1437604282
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604402
#   }
#   departure {
#     time: 1437604402
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604492
#   }
#   departure {
#     time: 1437604492
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604612
#   }
#   departure {
#     time: 1437604612
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604702
#   }
#   departure {
#     time: 1437604702
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604792
#   }
#   departure {
#     time: 1437604792
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604882
#   }
#   departure {
#     time: 1437604882
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604972
#   }
#   departure {
#     time: 1437604972
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605092
#   }
#   departure {
#     time: 1437605092
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605182
#   }
#   departure {
#     time: 1437605182
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605272
#   }
#   departure {
#     time: 1437605272
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605362
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "107050_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602669
#   }
#   departure {
#     time: 1437602669
#   }
#   stop_id: "111S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602789
#   }
#   departure {
#     time: 1437602789
#   }
#   stop_id: "112S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602879
#   }
#   departure {
#     time: 1437602879
#   }
#   stop_id: "113S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602999
#   }
#   departure {
#     time: 1437602999
#   }
#   stop_id: "114S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603089
#   }
#   departure {
#     time: 1437603089
#   }
#   stop_id: "115S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603179
#   }
#   departure {
#     time: 1437603179
#   }
#   stop_id: "116S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603329
#   }
#   departure {
#     time: 1437603329
#   }
#   stop_id: "117S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603389
#   }
#   departure {
#     time: 1437603389
#   }
#   stop_id: "118S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603449
#   }
#   departure {
#     time: 1437603449
#   }
#   stop_id: "119S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603569
#   }
#   departure {
#     time: 1437603569
#   }
#   stop_id: "120S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603689
#   }
#   departure {
#     time: 1437603689
#   }
#   stop_id: "121S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603749
#   }
#   departure {
#     time: 1437603749
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603839
#   }
#   departure {
#     time: 1437603839
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603929
#   }
#   departure {
#     time: 1437603929
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604019
#   }
#   departure {
#     time: 1437604019
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604139
#   }
#   departure {
#     time: 1437604139
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604259
#   }
#   departure {
#     time: 1437604259
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604349
#   }
#   departure {
#     time: 1437604349
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604439
#   }
#   departure {
#     time: 1437604439
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604499
#   }
#   departure {
#     time: 1437604499
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604559
#   }
#   departure {
#     time: 1437604559
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604619
#   }
#   departure {
#     time: 1437604619
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604709
#   }
#   departure {
#     time: 1437604709
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604799
#   }
#   departure {
#     time: 1437604799
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604889
#   }
#   departure {
#     time: 1437604889
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604949
#   }
#   departure {
#     time: 1437604949
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605039
#   }
#   departure {
#     time: 1437605159
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605249
#   }
#   departure {
#     time: 1437605249
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605339
#   }
#   departure {
#     time: 1437605519
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605669
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "107100_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602672
#   }
#   departure {
#     time: 1437602672
#   }
#   stop_id: "132N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602732
#   }
#   departure {
#     time: 1437602732
#   }
#   stop_id: "131N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602792
#   }
#   departure {
#     time: 1437602792
#   }
#   stop_id: "130N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602882
#   }
#   departure {
#     time: 1437602882
#   }
#   stop_id: "129N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602942
#   }
#   departure {
#     time: 1437602942
#   }
#   stop_id: "128N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603062
#   }
#   departure {
#     time: 1437603062
#   }
#   stop_id: "127N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603182
#   }
#   departure {
#     time: 1437603182
#   }
#   stop_id: "126N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603332
#   }
#   departure {
#     time: 1437603332
#   }
#   stop_id: "125N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603422
#   }
#   departure {
#     time: 1437603422
#   }
#   stop_id: "124N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603512
#   }
#   departure {
#     time: 1437603512
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603602
#   }
#   departure {
#     time: 1437603602
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603692
#   }
#   departure {
#     time: 1437603692
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603812
#   }
#   departure {
#     time: 1437603812
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603902
#   }
#   departure {
#     time: 1437603902
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603992
#   }
#   departure {
#     time: 1437603992
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604052
#   }
#   departure {
#     time: 1437604052
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604172
#   }
#   departure {
#     time: 1437604172
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604292
#   }
#   departure {
#     time: 1437604292
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604382
#   }
#   departure {
#     time: 1437604382
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604502
#   }
#   departure {
#     time: 1437604502
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604592
#   }
#   departure {
#     time: 1437604592
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604712
#   }
#   departure {
#     time: 1437604712
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604802
#   }
#   departure {
#     time: 1437604802
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604892
#   }
#   departure {
#     time: 1437604892
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604982
#   }
#   departure {
#     time: 1437604982
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605072
#   }
#   departure {
#     time: 1437605072
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605192
#   }
#   departure {
#     time: 1437605192
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605282
#   }
#   departure {
#     time: 1437605282
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605372
#   }
#   departure {
#     time: 1437605402
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605492
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "107500_1..N02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602753
#   }
#   departure {
#     time: 1437602753
#   }
#   stop_id: "133N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602873
#   }
#   departure {
#     time: 1437602873
#   }
#   stop_id: "132N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602933
#   }
#   departure {
#     time: 1437602933
#   }
#   stop_id: "131N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602993
#   }
#   departure {
#     time: 1437602993
#   }
#   stop_id: "130N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603083
#   }
#   departure {
#     time: 1437603083
#   }
#   stop_id: "129N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603143
#   }
#   departure {
#     time: 1437603143
#   }
#   stop_id: "128N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603263
#   }
#   departure {
#     time: 1437603263
#   }
#   stop_id: "127N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603383
#   }
#   departure {
#     time: 1437603383
#   }
#   stop_id: "126N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603533
#   }
#   departure {
#     time: 1437603533
#   }
#   stop_id: "125N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603623
#   }
#   departure {
#     time: 1437603623
#   }
#   stop_id: "124N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603713
#   }
#   departure {
#     time: 1437603713
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603803
#   }
#   departure {
#     time: 1437603803
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603893
#   }
#   departure {
#     time: 1437603893
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604013
#   }
#   departure {
#     time: 1437604013
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604103
#   }
#   departure {
#     time: 1437604103
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604193
#   }
#   departure {
#     time: 1437604193
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604253
#   }
#   departure {
#     time: 1437604253
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604373
#   }
#   departure {
#     time: 1437604373
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604493
#   }
#   departure {
#     time: 1437604493
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604583
#   }
#   departure {
#     time: 1437604583
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604703
#   }
#   departure {
#     time: 1437604703
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604793
#   }
#   departure {
#     time: 1437604793
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604913
#   }
#   departure {
#     time: 1437604913
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605003
#   }
#   departure {
#     time: 1437605003
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605093
#   }
#   departure {
#     time: 1437605093
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605183
#   }
#   departure {
#     time: 1437605183
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605273
#   }
#   departure {
#     time: 1437605273
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605393
#   }
#   departure {
#     time: 1437605393
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605483
#   }
#   departure {
#     time: 1437605483
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605573
#   }
#   departure {
#     time: 1437605633
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605723
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "107550_1..S02R"
#   start_date: "20150722"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1437602737
#   }
#   departure {
#     time: 1437602737
#   }
#   stop_id: "110S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602827
#   }
#   departure {
#     time: 1437602827
#   }
#   stop_id: "111S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602947
#   }
#   departure {
#     time: 1437602947
#   }
#   stop_id: "112S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603037
#   }
#   departure {
#     time: 1437603037
#   }
#   stop_id: "113S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603157
#   }
#   departure {
#     time: 1437603157
#   }
#   stop_id: "114S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603247
#   }
#   departure {
#     time: 1437603247
#   }
#   stop_id: "115S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603337
#   }
#   departure {
#     time: 1437603337
#   }
#   stop_id: "116S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603487
#   }
#   departure {
#     time: 1437603487
#   }
#   stop_id: "117S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603547
#   }
#   departure {
#     time: 1437603547
#   }
#   stop_id: "118S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603607
#   }
#   departure {
#     time: 1437603607
#   }
#   stop_id: "119S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603727
#   }
#   departure {
#     time: 1437603727
#   }
#   stop_id: "120S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603847
#   }
#   departure {
#     time: 1437603847
#   }
#   stop_id: "121S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603907
#   }
#   departure {
#     time: 1437603907
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603997
#   }
#   departure {
#     time: 1437603997
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604087
#   }
#   departure {
#     time: 1437604087
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604177
#   }
#   departure {
#     time: 1437604177
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604297
#   }
#   departure {
#     time: 1437604297
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604417
#   }
#   departure {
#     time: 1437604417
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604507
#   }
#   departure {
#     time: 1437604507
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604597
#   }
#   departure {
#     time: 1437604597
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604657
#   }
#   departure {
#     time: 1437604657
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604717
#   }
#   departure {
#     time: 1437604717
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604777
#   }
#   departure {
#     time: 1437604777
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604867
#   }
#   departure {
#     time: 1437604867
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604957
#   }
#   departure {
#     time: 1437604957
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605047
#   }
#   departure {
#     time: 1437605047
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605107
#   }
#   departure {
#     time: 1437605107
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605197
#   }
#   departure {
#     time: 1437605317
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605407
#   }
#   departure {
#     time: 1437605407
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605497
#   }
#   departure {
#     time: 1437605677
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
# ...
#   }
#   stop_id: "637S"
# }
# stop_time_update {
#   arrival {
#     time: 1437607560
#   }
#   departure {
#     time: 1437607560
#   }
#   stop_id: "638S"
# }
# stop_time_update {
#   arrival {
#     time: 1437607650
#   }
#   departure {
#     time: 1437607650
#   }
#   stop_id: "639S"
# }
# stop_time_update {
#   arrival {
#     time: 1437607770
#   }
#   stop_id: "640S"
# }
#
# trip {
#   trip_id: "111550_6..S03R"
#   start_date: "20150722"
#   route_id: "6"
# }
# stop_time_update {
#   departure {
#     time: 1437604530
#   }
#   stop_id: "608S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604620
#   }
#   departure {
#     time: 1437604620
#   }
#   stop_id: "609S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604710
#   }
#   departure {
#     time: 1437604710
#   }
#   stop_id: "610S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604770
#   }
#   departure {
#     time: 1437604770
#   }
#   stop_id: "611S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604860
#   }
#   departure {
#     time: 1437604860
#   }
#   stop_id: "612S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604980
#   }
#   departure {
#     time: 1437604980
#   }
#   stop_id: "613S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605070
#   }
#   departure {
#     time: 1437605070
#   }
#   stop_id: "614S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605190
#   }
#   departure {
#     time: 1437605190
#   }
#   stop_id: "615S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605250
#   }
#   departure {
#     time: 1437605250
#   }
#   stop_id: "616S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605370
#   }
#   departure {
#     time: 1437605370
#   }
#   stop_id: "617S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605430
#   }
#   departure {
#     time: 1437605430
#   }
#   stop_id: "618S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605520
#   }
#   departure {
#     time: 1437605520
#   }
#   stop_id: "619S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605700
#   }
#   departure {
#     time: 1437605700
#   }
#   stop_id: "621S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605790
#   }
#   departure {
#     time: 1437605790
#   }
#   stop_id: "622S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605880
#   }
#   departure {
#     time: 1437605880
#   }
#   stop_id: "623S"
# }
# stop_time_update {
#   arrival {
#     time: 1437605940
#   }
#   departure {
#     time: 1437605940
#   }
#   stop_id: "624S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606030
#   }
#   departure {
#     time: 1437606030
#   }
#   stop_id: "625S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606150
#   }
#   departure {
#     time: 1437606150
#   }
#   stop_id: "626S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606240
#   }
#   departure {
#     time: 1437606240
#   }
#   stop_id: "627S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606360
#   }
#   departure {
#     time: 1437606360
#   }
#   stop_id: "628S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606450
#   }
#   departure {
#     time: 1437606450
#   }
#   stop_id: "629S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606540
#   }
#   departure {
#     time: 1437606540
#   }
#   stop_id: "630S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606660
#   }
#   departure {
#     time: 1437606660
#   }
#   stop_id: "631S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606780
#   }
#   departure {
#     time: 1437606780
#   }
#   stop_id: "632S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606840
#   }
#   departure {
#     time: 1437606840
#   }
#   stop_id: "633S"
# }
# stop_time_update {
#   arrival {
#     time: 1437606900
#   }
#   departure {
#     time: 1437606900
#   }
#   stop_id: "634S"
# }
# stop_time_update {
#   arrival {
#     time: 1437607020
#   }
#   departure {
#     time: 1437607020
#   }
#   stop_id: "635S"
# }
# stop_time_update {
#   arrival {
#     time: 1437607110
#   }
#   departure {
#     time: 1437607110
#   }
#   stop_id: "636S"
# }
# stop_time_update {
#   arrival {
#     time: 1437607200
#   }
#   departure {
#     time: 1437607200
#   }
#   stop_id: "637S"
# }
# stop_time_update {
#   arrival {
#     time: 1437607260
#   }
#   departure {
#     time: 1437607260
#   }
#   stop_id: "638S"
# }
# stop_time_update {
#   arrival {
#     time: 1437607350
#   }
#   departure {
#     time: 1437607350
#   }
#   stop_id: "639S"
# }
# stop_time_update {
#   arrival {
#     time: 1437607470
#   }
#   stop_id: "640S"
# }
#
# trip {
#   trip_id: "111550_6..N02R"
#   start_date: "20150722"
#   route_id: "6X"
# }
# stop_time_update {
#   departure {
#     time: 1437604530
#   }
#   stop_id: "640N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604650
#   }
#   departure {
#     time: 1437604650
#   }
#   stop_id: "639N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604740
#   }
#   departure {
#     time: 1437604740
#   }
#   stop_id: "638N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604830
#   }
#   departure {
#     time: 1437604830
#   }
#   stop_id: "637N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604920
#   }
#   departure {
#     time: 1437604920
#   }
#   stop_id: "636N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605010
#   }
#   departure {
#     time: 1437605010
#   }
#   stop_id: "635N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605130
#   }
#   departure {
#     time: 1437605130
#   }
#   stop_id: "634N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605190
#   }
#   departure {
#     time: 1437605190
#   }
#   stop_id: "633N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605280
#   }
#   departure {
#     time: 1437605280
#   }
#   stop_id: "632N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605400
#   }
#   departure {
#     time: 1437605400
#   }
#   stop_id: "631N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605520
#   }
#   departure {
#     time: 1437605520
#   }
#   stop_id: "630N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605610
#   }
#   departure {
#     time: 1437605610
#   }
#   stop_id: "629N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605730
#   }
#   departure {
#     time: 1437605730
#   }
#   stop_id: "628N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605820
#   }
#   departure {
#     time: 1437605820
#   }
#   stop_id: "627N"
# }
# stop_time_update {
#   arrival {
#     time: 1437605940
#   }
#   departure {
#     time: 1437605940
#   }
#   stop_id: "626N"
# }
# stop_time_update {
#   arrival {
#     time: 1437606060
#   }
#   departure {
#     time: 1437606060
#   }
#   stop_id: "625N"
# }
# stop_time_update {
#   arrival {
#     time: 1437606150
#   }
#   departure {
#     time: 1437606150
#   }
#   stop_id: "624N"
# }
# stop_time_update {
#   arrival {
#     time: 1437606240
#   }
#   departure {
#     time: 1437606240
#   }
#   stop_id: "623N"
# }
# stop_time_update {
#   arrival {
#     time: 1437606300
#   }
#   departure {
#     time: 1437606300
#   }
#   stop_id: "622N"
# }
# stop_time_update {
#   arrival {
#     time: 1437606420
#   }
#   departure {
#     time: 1437606420
#   }
#   stop_id: "621N"
# }
# stop_time_update {
#   arrival {
#     time: 1437606600
#   }
#   departure {
#     time: 1437606600
#   }
#   stop_id: "619N"
# }
# stop_time_update {
#   arrival {
#     time: 1437607020
#   }
#   departure {
#     time: 1437607020
#   }
#   stop_id: "613N"
# }
# stop_time_update {
#   arrival {
#     time: 1437607380
#   }
#   departure {
#     time: 1437607440
#   }
#   stop_id: "608N"
# }
# stop_time_update {
#   arrival {
#     time: 1437607560
#   }
#   departure {
#     time: 1437607560
#   }
#   stop_id: "607N"
# }
# stop_time_update {
#   arrival {
#     time: 1437607620
#   }
#   departure {
#     time: 1437607620
#   }
#   stop_id: "606N"
# }
# stop_time_update {
#   arrival {
#     time: 1437607680
#   }
#   departure {
#     time: 1437607680
#   }
#   stop_id: "604N"
# }
# stop_time_update {
#   arrival {
#     time: 1437607770
#   }
#   departure {
#     time: 1437607770
#   }
#   stop_id: "603N"
# }
# stop_time_update {
#   arrival {
#     time: 1437607860
#   }
#   departure {
#     time: 1437607860
#   }
#   stop_id: "602N"
# }
# stop_time_update {
#   arrival {
#     time: 1437608010
#   }
#   stop_id: "601N"
# }
#
# trip {
#   trip_id: "104650_6..N02R"
#   start_date: "20150722"
#   route_id: "6X"
# }
# stop_time_update {
#   arrival {
#     time: 1437602618
#   }
#   departure {
#     time: 1437602618
#   }
#   stop_id: "624N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602708
#   }
#   departure {
#     time: 1437602708
#   }
#   stop_id: "623N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602768
#   }
#   departure {
#     time: 1437602768
#   }
#   stop_id: "622N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602888
#   }
#   departure {
#     time: 1437602888
#   }
#   stop_id: "621N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603098
#   }
#   departure {
#     time: 1437603098
#   }
#   stop_id: "619N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603518
#   }
#   departure {
#     time: 1437603518
#   }
#   stop_id: "613N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603878
#   }
#   departure {
#     time: 1437603878
#   }
#   stop_id: "608N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603998
#   }
#   departure {
#     time: 1437603998
#   }
#   stop_id: "607N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604058
#   }
#   departure {
#     time: 1437604058
#   }
#   stop_id: "606N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604118
#   }
#   departure {
#     time: 1437604118
#   }
#   stop_id: "604N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604208
#   }
#   departure {
#     time: 1437604208
#   }
#   stop_id: "603N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604298
#   }
#   departure {
#     time: 1437604298
#   }
#   stop_id: "602N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604448
#   }
#   stop_id: "601N"
# }
#
# trip {
#   trip_id: "108300_GS.S03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   arrival {
#     time: 1437602722
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "108400_GS.N01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   arrival {
#     time: 1437602746
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "108550_GS.S04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437602730
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602820
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "108600_GS.N03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437602760
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437602850
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "108750_GS.S01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437602850
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437602940
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "108850_GS.N04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437602910
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603000
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "108950_GS.S03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437602970
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603060
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "109050_GS.N01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603030
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603120
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "109200_GS.S04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603120
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603210
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "109250_GS.N03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603150
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603240
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "109400_GS.S01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603240
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603330
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "109500_GS.N04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603300
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603390
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "109600_GS.S03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603360
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603450
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "109700_GS.N01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603420
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603510
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "109850_GS.S04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603510
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603600
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "109900_GS.N03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603540
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603630
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "110050_GS.S01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603630
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603720
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "110150_GS.N04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603690
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603780
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "110250_GS.S03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603750
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603840
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "110350_GS.N01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603810
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437603900
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "110500_GS.S04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603900
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437603990
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "110550_GS.N03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437603930
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604020
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "110700_GS.S01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437604020
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604110
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "110800_GS.N04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437604080
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604170
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "110900_GS.S03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437604140
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604230
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "111050_GS.N01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437604230
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604320
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "111150_GS.S04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437604290
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604380
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "111300_GS.N03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437604380
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604470
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "111400_GS.S01R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437604440
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604530
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "111550_GS.N04R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437604530
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1437604620
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "111650_GS.S03R"
#   start_date: "20150722"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1437604590
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1437604680
#   }
#   stop_id: "901S"
# }

# %%
len(feed.entity)
# Out:
# 454

# %%
# trip ID
feed.entity[2].trip_update.trip.trip_id
# Out:
# u'102100_1..S02R'

# %%
# length of stop time update
len(feed.entity[2].trip_update.stop_time_update)
# Out:
# 1

# %%
# stop ID
feed.entity[2].trip_update.stop_time_update[1].stop_id
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-635395ea2e8f> in <module>()
#       1 # stop ID
# ----> 2 feed.entity[1].trip_update.stop_time_update[1].stop_id
#
# C:\Anaconda\lib\site-packages\protobuf-3.0.0a3-py2.7.egg\google\protobuf\internal\containers.py in __getitem__(self, key)
#     201   def __getitem__(self, key):
#     202     """Retrieves item by the specified key."""
# --> 203     return self._values[key]
#     204
#     205   def __len__(self):
#
# IndexError: list index out of range

# %%
# time
feed.entity[2].trip_update.stop_time_update[1].arrival.time
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-15c22a115e93> in <module>()
#       1 # time
# ----> 2 feed.entity[2].trip_update.stop_time_update[1].arrival.time
#
# C:\Anaconda\lib\site-packages\protobuf-3.0.0a3-py2.7.egg\google\protobuf\internal\containers.py in __getitem__(self, key)
#     201   def __getitem__(self, key):
#     202     """Retrieves item by the specified key."""
# --> 203     return self._values[key]
#     204
#     205   def __len__(self):
#
# IndexError: list index out of range

# %%
#system time
datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S')
# Out:
# '2015-07-07 22:30:42'

# %%
print feed.entity[2]
# Out:
# id: "000003"
# trip_update {
#   trip {
#     trip_id: "128800_1..N02R"
#     start_date: "20150707"
#     route_id: "1"
#   }
#   stop_time_update {
#     arrival {
#       time: 1436322539
#     }
#     stop_id: "101N"
#   }
# }

# %%
### save in file definition
def savefile(listitems):
    # 'a' to add line to txt file
    with open('mta.txt', 'a') as f:
            f.write(listitems + '\n')

# %%
## draft of the loop

#system time
tmpSys = datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S')

i = 1

entity=feed.entity[2]
if entity.HasField('trip_update'):
    
    ## trip update: 3 data characterisitcs
    TripIdi = entity.trip_update.trip.trip_id
    StartDatei = entity.trip_update.trip.start_date
    Routei = entity.trip_update.trip.route_id
    
    ## trip alert: 1 data characterisitcs
    if entity.HasField('alert'):
        Alerti = entity.alert.header_text
    else:
        Alerti = ''
    
    ## looking to record first 3 predicted arrival time 
    Arrivetmp=[]
    stop_id=[]
    
    tripcomplete = []
    
    if len(entity.trip_update.stop_time_update) <> 0:
        #record only first three trip updates
        p3trip = min(len(entity.trip_update.stop_time_update),3)
        
        j=0
        while j < p3trip:
            tripcomplete = []
            #print j
            ArrivalTime = entity.trip_update.stop_time_update[j].arrival.time
            stop_id = entity.trip_update.stop_time_update[j].stop_id
            
            tripcomplete.extend([tmpSys,TripIdi,StartDatei,Routei,Alerti,stop_id,ArrivalTime])
            print tripcomplete, type(tripcomplete)
            tripcomplstr = ','.join([str(i) for i in tripcomplete])
            savefile(tripcomplstr)
            
            j+=1
# Out:
# ['2015-07-07 22:30:47', u'128800_1..N02R', u'20150707', u'1', '', u'101N', 1436322539L] <type 'list'>

# %%
# Perturbation on MTA info -- webscraping of mta.info :

#definition of extracting function 

def extract_url_content(urlv, headersv):
        # Request by url and headers
        req =  requests.get(urlv, headers=headers)
        demande = req.text
        # Request status code
        statut_demande = req.status_code
        if statut_demande/100 in [4,5]:
            return 'error on requests with error: ', statut_demande
        return BeautifulSoup(demande)

# %%
# Perturbation on MTA info -- webscraping of mta.info :

#draft for the delays for different lines from mta.info

url = 'http://www.mta.info/status/subway/123'

headers = None

texturl = extract_url_content(url, headers)
print texturl.prettify
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html dir="ltr" version="XHTML+RDFa 1.0" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/terms/" xmlns:foaf="http://xmlns.com/foaf/0.1/" xmlns:og="http://ogp.me/ns#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:sioc="http://rdfs.org/sioc/ns#" xmlns:sioct="http://rdfs.org/sioc/types#" xmlns:skos="http://www.w3.org/2004/02/skos/core#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
# <head profile="http://www.w3.org/1999/xhtml/vocab">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="http://www.mta.info/sites/default/files/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed" type="image/png"/>
# <link href="http://www.mta.info/sites/default/files/apple-touch-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="http://www.mta.info/sites/all/themes/mta/images/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
# <title>MTA Service Status | MTA</title>
# <link href="http://www.mta.info/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.mta.info/sites/default/files/css/css_1BT3BPx-E-ZT0OvT0jz8a_fBsZpJCUj1DJqdI6Tr2lE.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.mta.info/sites/default/files/css/css_jxJkoHdzRdN1uuX4xCmTe-7uY81-ZptxpPdM13bF4I8.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.mta.info/sites/default/files/css/css_KmGWBphApymF3PTkHC22wkDsMo03rkga-AoKBOHGaK4.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="http://www.mta.info/sites/default/files/js/js_xAPl0qIk9eowy_iS9tNkCWXLUVoat94SQT48UBCFkyQ.js" type="text/javascript"></script>
# <script src="http://www.mta.info/sites/default/files/js/js_wVijrHU6k3obWosLX-Dc0Iu41bE7KytA82kbAjMuGmQ.js" type="text/javascript"></script>
# <script src="http://www.mta.info/sites/default/files/js/js_3Oissr0TLlayMUE1D0qb2eWdDx8Wozb8u0yAeGI145k.js" type="text/javascript"></script>
# <script src="http://translate.google.com/translate_a/element.js?cb=googleTranslateElementInit" type="text/javascript"></script>
# <script src="http://www.mta.info/sites/default/files/js/js_I8yX6RYPZb7AtMcDUA3QKDZqVkvEn35ED11_1i7vVpc.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","http://www.mta.info/sites/default/files/googleanalytics/analytics.js?nr4f75","ga");ga("create", "UA-20245417-1", {"cookieDomain":"auto"});ga("send", "pageview");
# //--><!]]>
# </script>
# <script src="http://www.mta.info/sites/default/files/js/js_K5xoxCnrq_vHutN9KzVFQGvBMf94d_vlf-Y0lyTyz-0.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"mta","theme_token":"pMmECSgCZY05coPyeOOYAvQPiF1p09EMu7ZUlOYa1wk","js":{"misc\/jquery.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/custom\/servicestatus\/servicestatus.js":1,"sites\/all\/modules\/custom\/servicestatus\/jquery.cookie.js":1,"sites\/all\/modules\/contrib\/blockcache_alter\/blockcache_alter.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/contrib\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.js":1,"http:\/\/translate.google.com\/translate_a\/element.js?cb=googleTranslateElementInit":1,"sites\/all\/modules\/contrib\/google_analytics\/googleanalytics.js":1,"0":1,"sites\/all\/libraries\/superfish\/jquery.hoverIntent.minified.js":1,"sites\/all\/libraries\/superfish\/supposition.js":1,"sites\/all\/libraries\/superfish\/jquery.bgiframe.min.js":1,"sites\/all\/libraries\/superfish\/superfish.js":1,"sites\/all\/modules\/contrib\/superfish\/superfish.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"modules\/aggregator\/aggregator.css":1,"modules\/book\/book.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/contrib\/google_appliance\/theme\/google_appliance.css":1,"modules\/node\/node.css":1,"sites\/all\/modules\/custom\/servicestatus\/service_status_style.css":1,"sites\/all\/modules\/custom\/tripplanner\/tripplanner.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/libraries\/superfish\/css\/superfish.css":1,"sites\/all\/libraries\/superfish\/style\/default.css":1,"sites\/all\/themes\/mta\/css\/global.css":1,"sites\/all\/themes\/mta\/css\/fields.css":1,"sites\/all\/themes\/mta\/css\/blocks.css":1,"sites\/all\/themes\/mta\/css\/grid.css":1,"sites\/all\/themes\/mta\/css\/mtaviews.css":1,"sites\/all\/themes\/mta\/css\/homepage.css":1,"sites\/all\/themes\/mta\/css\/topbar.css":1,"sites\/all\/themes\/mta\/css\/webform.css":1,"sites\/all\/themes\/mta\/css\/capital_style.css":1,"sites\/all\/themes\/mta\/css\/weekender.css":1}},"colorbox":{"opacity":"0.85","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","maxWidth":"98%","maxHeight":"98%","fixed":true,"mobiledetect":true,"mobiledevicewidth":"480px"},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip"},"superfish":{"1":{"id":"1","sf":{"delay":"200","animation":{"opacity":"show"},"speed":20,"autoArrows":false,"dropShadows":false,"disableHI":false},"plugins":{"supposition":true,"bgiframe":true}}}});
# //--><!]]>
# </script>
# <script type="text/javascript">
#                     var AKSB=AKSB||{};AKSB.q=[];AKSB.mark=function(c,a){AKSB.q.push(["mark",c,a||(new Date).getTime()])};AKSB.measure=function(c,a,b){AKSB.q.push(["measure",c,a,b||(new Date).getTime()])};AKSB.done=function(c){AKSB.q.push(["done",c])};AKSB.mark("firstbyte",(new Date).getTime());
#                     AKSB.prof={custid:"141952",ustr:"",originlat:0,clientrtt:30,ghostip:"23.77.207.43",ipv6:false,pct:10,xhrtest:false,clientip:"100.37.250.143",requestid:"20627fca",protocol:"",akM:"b",akN:"ae"};
#                     (function(c){var a=document.createElement("iframe");a.src="javascript:false";(a.frameElement||a).style.cssText="width: 0; height: 0; border: 0; display: none";var b=document.getElementsByTagName("script"),b=b[b.length-1];b.parentNode.insertBefore(a,b);a=a.contentWindow.document;b=String.fromCharCode;c=b(60)+"body onload=\"var js = document.createElement('script');js.id = 'aksb-ifr';js.src = '"+c+"';document.body.appendChild(js);\""+b(62);a.open().write(c);a.close()})(("https:"===document.location.protocol?
#                     "https:":"http:")+"//ds-aksb-a.akamaihd.net/aksb.min.js");
#                   </script>
# </head>
# <body class="html not-front not-logged-in one-sidebar sidebar-second page-status page-status-subway page-status-subway- page-status-subway-123">
# <div id="skip-link">
# <a class="element-invisible element-focusable" href="#main-content">Skip to main content</a>
# </div>
# <div id="page">
# <div id="mainbox">
# <div id="topbar">
# <div id="branding">
# <a href="http://www.mta.info"><img alt="Metropolitan Transportation Authority logo" src="/sites/all/themes/mta/images/mta_info.gif"/></a>
# </div>
# <div id="middle-header">
# </div>
# <div id="search">
# <div class="region region-header-right">
# <div class="block block-menu" id="block-menu-menu-topbar-links">
# <div class="content">
# <ul class="menu"><li class="first leaf"><a href="http://web.mta.info/accessibility" title="">Accessibility</a></li>
# <li class="leaf"><a href="http://assistive.usablenet.com/tt/www.mta.info" title="">Text-only</a></li>
# <li class="leaf"><a href="http://web.mta.info/selfserve" title="">Customer Self-Service</a></li>
# <li class="leaf"><a href="http://web.mta.info/mta/employment" title="">Employment</a></li>
# <li class="last leaf"><a href="http://web.mta.info/faqs.htm" title="">FAQs/Contact Us</a></li>
# </ul> </div>
# </div>
# <div class="block block-google-appliance" id="block-google-appliance-ga-block-search-form">
# <div class="content">
# <form accept-charset="UTF-8" action="/status/subway/123" id="google-appliance-block-form" method="post"><div><div class="container-inline">
# <h2 class="element-invisible">Search Google Appliance</h2>
# <div class="form-item form-type-textfield form-item-search-keys">
# <label class="element-invisible" for="edit-search-keys">Enter the terms you wish to search for. </label>
# <input class="form-text" id="edit-search-keys" maxlength="128" name="search_keys" size="15" type="text" value=""/>
# </div>
# <div class="form-actions form-wrapper" id="edit-actions"><input class="form-submit" id="edit-submit" name="op" type="submit" value="Search"/></div><input name="form_build_id" type="hidden" value="form-nSO8DqGPTvT4aicJeVbnQ4lbqnY_gxPz0f07rksarFg"/>
# <input name="form_id" type="hidden" value="google_appliance_block_form"/>
# </div>
# </div></form> </div>
# </div>
# </div>
# </div>
# </div>
# <div id="navbar"> <div class="region region-navbar">
# <div class="block block-superfish" id="block-superfish-1">
# <div class="content">
# <ul class="menu sf-menu sf-main-menu sf-horizontal sf-style-default sf-total-items-8 sf-parent-items-2 sf-single-items-6" id="superfish-1"><li class="first odd sf-item-1 sf-depth-1 sf-total-children-6 sf-parent-children-0 sf-single-children-6 menuparent" id="menu-221-1"><a class="sf-depth-1 menuparent" href="http://www.mta.info" title="">Home</a><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-400-1"><a class="sf-depth-2" href="http://www.mta.info" title="">MTA Home</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-401-1"><a class="sf-depth-2" href="/nyct" title="">NYC Subways and Buses</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-402-1"><a class="sf-depth-2" href="/lirr">Long Island Rail Road</a></li><li class="middle even sf-item-4 sf-depth-2 sf-no-children" id="menu-403-1"><a class="sf-depth-2" href="/mnr">Metro-North Railroad</a></li><li class="middle odd sf-item-5 sf-depth-2 sf-no-children" id="menu-404-1"><a class="sf-depth-2" href="/bandt">Bridges and Tunnels</a></li><li class="last even sf-item-6 sf-depth-2 sf-no-children" id="menu-405-1"><a class="sf-depth-2" href="http://web.mta.info/capital" title="">MTA Capital Program</a></li></ul></li><li class="middle even sf-item-2 sf-depth-1 sf-no-children" id="menu-399-1"><a class="sf-depth-1" href="http://www.mta.info/schedules" title="">Schedules</a></li><li class="middle odd sf-item-3 sf-depth-1 sf-no-children" id="menu-414-1"><a class="sf-depth-1" href="http://web.mta.info/fares" title="">Fares &amp; Tolls</a></li><li class="middle even sf-item-4 sf-depth-1 sf-no-children" id="menu-415-1"><a class="sf-depth-1" href="http://web.mta.info/maps" title="">Maps</a></li><li class="middle odd sf-item-5 sf-depth-1 sf-no-children" id="menu-416-1"><a class="sf-depth-1" href="http://web.mta.info/service" title="">Planned Service Changes</a></li><li class="middle even sf-item-6 sf-depth-1 sf-no-children" id="menu-417-1"><a class="sf-depth-1" href="http://web.mta.info/about" title="">MTA Info</a></li><li class="middle odd sf-item-7 sf-depth-1 sf-no-children" id="menu-418-1"><a class="sf-depth-1" href="http://web.mta.info/business" title="">Doing Business With Us</a></li><li class="last even sf-item-8 sf-depth-1 sf-total-children-9 sf-parent-children-0 sf-single-children-9 menuparent" id="menu-419-1"><a class="sf-depth-1 menuparent" href="http://web.mta.info/accountability" title="">Transparency</a><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-420-1"><a class="sf-depth-2" href="http://web.mta.info/accountability" title="">Main Page</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-421-1"><a class="sf-depth-2" href="http://web.mta.info/mta/boardmaterials.html" title="">Board Materials</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-422-1"><a class="sf-depth-2" href="http://web.mta.info/mta/budget/" title="">Budget Info</a></li><li class="middle even sf-item-4 sf-depth-2 sf-no-children" id="menu-423-1"><a class="sf-depth-2" href="http://web.mta.info/capital/" title="">Capital Program Info</a></li><li class="middle odd sf-item-5 sf-depth-2 sf-no-children" id="menu-428-1"><a class="sf-depth-2" href="http://web.mta.info/capitaldashboard/CPDHome.html" title="">Capital Program Dashboard</a></li><li class="middle even sf-item-6 sf-depth-2 sf-no-children" id="menu-424-1"><a class="sf-depth-2" href="http://web.mta.info/mta/leadership/" title="">MTA Leadership</a></li><li class="middle odd sf-item-7 sf-depth-2 sf-no-children" id="menu-425-1"><a class="sf-depth-2" href="http://web.mta.info/persdashboard/performance14.html" title="">Performance Indicators</a></li><li class="middle even sf-item-8 sf-depth-2 sf-no-children" id="menu-426-1"><a class="sf-depth-2" href="/mta-news" title="">Press Releases and News</a></li><li class="last odd sf-item-9 sf-depth-2 sf-no-children" id="menu-427-1"><a class="sf-depth-2" href="http://web.mta.info/mta/new ...
# </div>
# </div>
# </div>
# <div id="breadcrumb"> <!-- we leave the div and keep spacing -->
# </div>
# <div class="container">
# <a name="main-content"></a>
# <div class="span-ad roundCorners">
# <div id="pageTitleAreaAd">
# <h1 class="title" id="page-title-ad">MTA Service Status</h1>
# </div>
# <div id="main-ad-content">
# <div class="tabs"></div> <div class="span-no-side-ad">
# <div id="status_display">The Service Status has changed. Please go back to the MTA home page for latest status.</div>
# </div>
# <!-- close span-43 -->
# </div>
# <!-- close span-21 last -->
# </div><!-- close container for grid -->
# <div class="column sidebar" id="sidebar_second_ad"><div class="section roundCorners">
# <div class="region region-sidebar-second">
# <div class="block block-google-adsense" id="block-google-adsense-google-adsense">
# <div class="content">
# <div id="Google-skyscraper-ad">
# <script type="text/javascript">
# 		<!--
# 		google_ad_client = "pub-0982027042052701";
# 		/* 160x600, created 5/6/11 */
# 		google_ad_slot = "8916589146";
# 		google_ad_width = 160;
# 		google_ad_height = 600;
#       		-->
#
#       	</script> <script src="http://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript"></script> </div> </div>
# </div>
# </div>
# </div></div> <!-- /.section, /#sidebar_second -->
# </div>
# <div id="foot-div">
# <div class="region region-footer">
# <div class="block block-google-translate" id="block-google-translate-google-translate">
# <div class="content">
# <div id="google_translate_element"></div><script>function googleTranslateElementInit() {
#   new google.translate.TranslateElement({
#     pageLanguage: 'en',
#     layout: google.translate.TranslateElement.InlineLayout.SIMPLE}, 'google_translate_element');
# }</script> </div>
# </div>
# </div>
# </div>
# </div>
# </div></body>
# </html>
# >

# %%
# Perturbation on MTA info -- webscraping of mta.info :

## draft of extraction of lines perturbated

Delaystext = texturl.find(class_="TitleDelay").get_text()
print Delaystext

lineaffected001 = texturl.findAll(id='status_display')
#print lineaffected001
lineaffected002 = [i.findAll('img') for i in lineaffected001]
print lineaffected002
print len(lineaffected002)
for j in range(len(lineaffected002)):
    textaffected001 = [i['alt'][:1] for i in lineaffected002[j]]
textaffected001
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-3593f4bc24cc> in <module>()
#       3 ## draft of extraction of lines perturbated
#       4
# ----> 5 Delaystext = texturl.find(class_="TitleDelay").get_text()
#       6 print Delaystext
#       7
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
## perturbations on MTA lines are publised here:

urllist = [
    'http://www.mta.info/status/subway/123',
    'http://www.mta.info/status/subway/456',
    'http://www.mta.info/status/subway/7',
    'http://www.mta.info/status/subway/ACE',
    'http://www.mta.info/status/subway/BDFM',
    'http://www.mta.info/status/subway/JZ',
    'http://www.mta.info/status/subway/L',
    'http://www.mta.info/status/subway/NQR',
    'http://www.mta.info/status/subway/S'
]

# %%
## Summary of the loop
def listofperturbations(listOfLines):
    
    ## webscraping of mta/info using the list of url listed above
    linesperturbated = []
    for url in listOfLines:
        headers = None
        urlbody = extract_url_content(url, headers)
        #print url, 'find TitleDelay',  urlbody.find(class_="TitleDelay")
        
        if urlbody.find(class_="TitleDelay") <> None:
            Delaystext = urlbody.find(class_="TitleDelay").get_text()
            #print 'delaystext', Delaystext
            if Delaystext == "Delays":
                lineaffected001 = urlbody.findAll(id='status_display')
                lineaffected002 = [i.findAll('img') for i in lineaffected001]
                #print 'line affectd 002', lineaffected002
            for j in range(len(lineaffected002)):
                    #print j
                    for i in lineaffected002[j]:
                        try:
                            linesperturbated.extend(i['alt'][:1])
                        except:
                            continue
                            
                    #textaffected001 = [i for i in lineaffected002[j]]
                    #print textaffected001
                    #linesperturbated.extend(textaffected001)
    return linesperturbated

# %%
listofperturbations(urllist)
# Out:
# []

# %%
def loopdwlmta(x):
    
    #system time for reference
    tmpSys = datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S')
    
    ##load list of lines perturbated
    listlineperturbated = listofperturbations(urllist)

    ## send request to api mta.info using my own key
    feed = gtfs_realtime_pb2.FeedMessage()
    response = urllib.urlopen('http://datamine.mta.info/mta_esi.php?key=5a8f6f4375e9f4bdea9b0c86afeaf911')
    feed.ParseFromString(response.read())
    
    
    ## looping the content downloaded
    for entity in feed.entity:
        if entity.HasField('trip_update'):
    
            ## trip update: 3 data characterisitcs
            TripIdi = entity.trip_update.trip.trip_id
            StartDatei = entity.trip_update.trip.start_date
            Routei = entity.trip_update.trip.route_id
            if Routei in listlineperturbated:
                Delaysi = "delays"
            else:
                Delaysi = ""

            ## trip alert: 1 data characterisitcs
            if entity.HasField('alert'):
                Alerti = entity.alert.header_text
            else:
                Alerti = ''

            ## looking to record first 3 predicted arrival time 
            Arrivetmp=[]
            stop_id=[]

            tripcomplete = []

            if len(entity.trip_update.stop_time_update) <> 0:
                #record only first three trip updates
                p3trip = min(len(entity.trip_update.stop_time_update),1)

                j=0
                while j < p3trip:
                    tripcomplete = []
                    #print j
                    ArrivalTime = entity.trip_update.stop_time_update[j].arrival.time
                    stop_id = entity.trip_update.stop_time_update[j].stop_id
                    station_nth=j

                    tripcomplete.extend([tmpSys,TripIdi,StartDatei,Routei,Alerti,station_nth,stop_id,ArrivalTime,Delaysi])
                    #print tripcomplete, type(tripcomplete)
                    tripcomplstr = ','.join([str(i) for i in tripcomplete])
                    savefile(tripcomplstr)

                    j+=1

# %%
# test function defined above
loopdwlmta(1)

# %%
linesperturbated = []
for url in urllist:
    headers = None
    texturl2 = extract_url_content(url, headers)
    print  texturl2.find(class_="TitleDelay") 
    if texturl2.find(class_="TitleDelay") <> None:
        Delaystext = texturl2.find(class_="TitleDelay").get_text()
        if Delaystext == "Delays":
            lineaffected001 = texturl2.findAll(id='status_display')
            lineaffected002 = [i.findAll('img') for i in lineaffected001]
            print lineaffected002
            for j in range(len(lineaffected002)):
                    #print j
                    for i in lineaffected002[j]:
                        try:
                            linesperturbated.extend(i['alt'][:1])
                        except:
                            continue
                            
                    #textaffected001 = [i for i in lineaffected002[j]]
                    #print textaffected001
                    #linesperturbated.extend(textaffected001)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
linesperturbated
# Out:
# []

# %%
import time 
while True:
    try: 
        loopdwlmta(1)
    except:
        continue
    time.sleep(300)
