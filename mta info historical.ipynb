# %%
from google.transit import gtfs_realtime_pb2
import urllib
import time
import datetime

from bs4 import BeautifulSoup
import requests
import re

# %%
## pulling info from api

feed = gtfs_realtime_pb2.FeedMessage()
response = urllib.urlopen('http://datamine.mta.info/mta_esi.php?key=5a8f6f4375e9f4bdea9b0c86afeaf911')
feed.ParseFromString(response.read())
for entity in feed.entity:
  if entity.HasField('trip_update'):
    print entity.trip_update
# Out:
# trip {
#   trip_id: "045000_2..S"
#   start_date: "20150908"
#   route_id: "2"
# }
# stop_time_update {
#   arrival {
#     time: 1441718579
#   }
#   departure {
#     time: 1441718579
#   }
#   stop_id: "246S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718729
#   }
#   stop_id: "247S"
# }
#
# trip {
#   trip_id: "045900_2..S05R"
#   start_date: "20150908"
#   route_id: "2"
# }
# stop_time_update {
#   arrival {
#     time: 1441718609
#   }
#   stop_id: "247S"
# }
#
# trip {
#   trip_id: "046300_2..S06R"
#   start_date: "20150908"
#   route_id: "2"
# }
# stop_time_update {
#   arrival {
#     time: 1441718590
#   }
#   departure {
#     time: 1441718650
#   }
#   stop_id: "250S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718830
#   }
#   departure {
#     time: 1441718830
#   }
#   stop_id: "251S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718920
#   }
#   departure {
#     time: 1441718920
#   }
#   stop_id: "252S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719040
#   }
#   departure {
#     time: 1441719040
#   }
#   stop_id: "253S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719100
#   }
#   departure {
#     time: 1441719100
#   }
#   stop_id: "254S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719220
#   }
#   departure {
#     time: 1441719220
#   }
#   stop_id: "255S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719280
#   }
#   departure {
#     time: 1441719280
#   }
#   stop_id: "256S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719370
#   }
#   stop_id: "257S"
# }
#
# trip {
#   trip_id: "046750_2..S05R"
#   start_date: "20150908"
#   route_id: "2"
# }
# stop_time_update {
#   arrival {
#     time: 1441718678
#   }
#   departure {
#     time: 1441718678
#   }
#   stop_id: "239S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718858
#   }
#   departure {
#     time: 1441718858
#   }
#   stop_id: "241S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718948
#   }
#   departure {
#     time: 1441718948
#   }
#   stop_id: "242S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719038
#   }
#   departure {
#     time: 1441719038
#   }
#   stop_id: "243S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719128
#   }
#   departure {
#     time: 1441719128
#   }
#   stop_id: "244S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719218
#   }
#   departure {
#     time: 1441719218
#   }
#   stop_id: "245S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719308
#   }
#   departure {
#     time: 1441719308
#   }
#   stop_id: "246S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719458
#   }
#   stop_id: "247S"
# }
#
# trip {
#   trip_id: "048300_1..S02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   departure {
#     time: 1441713780
#   }
#   stop_id: "101S"
# }
# stop_time_update {
#   arrival {
#     time: 1441713870
#   }
#   departure {
#     time: 1441713870
#   }
#   stop_id: "103S"
# }
# stop_time_update {
#   arrival {
#     time: 1441713960
#   }
#   departure {
#     time: 1441713960
#   }
#   stop_id: "104S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714050
#   }
#   departure {
#     time: 1441714050
#   }
#   stop_id: "106S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714140
#   }
#   departure {
#     time: 1441714140
#   }
#   stop_id: "107S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714200
#   }
#   departure {
#     time: 1441714200
#   }
#   stop_id: "108S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714290
#   }
#   departure {
#     time: 1441714290
#   }
#   stop_id: "109S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714380
#   }
#   departure {
#     time: 1441714380
#   }
#   stop_id: "110S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714470
#   }
#   departure {
#     time: 1441714470
#   }
#   stop_id: "111S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714590
#   }
#   departure {
#     time: 1441714590
#   }
#   stop_id: "112S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714710
#   }
#   departure {
#     time: 1441714710
#   }
#   stop_id: "113S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714830
#   }
#   departure {
#     time: 1441714830
#   }
#   stop_id: "114S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714920
#   }
#   departure {
#     time: 1441714920
#   }
#   stop_id: "115S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715040
#   }
#   departure {
#     time: 1441715040
#   }
#   stop_id: "116S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715160
#   }
#   departure {
#     time: 1441715160
#   }
#   stop_id: "117S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715220
#   }
#   departure {
#     time: 1441715220
#   }
#   stop_id: "118S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715310
#   }
#   departure {
#     time: 1441715310
#   }
#   stop_id: "119S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715430
#   }
#   departure {
#     time: 1441715430
#   }
#   stop_id: "120S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715550
#   }
#   departure {
#     time: 1441715550
#   }
#   stop_id: "121S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715640
#   }
#   departure {
#     time: 1441715640
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715730
#   }
#   departure {
#     time: 1441715730
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715820
#   }
#   departure {
#     time: 1441715820
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715910
#   }
#   departure {
#     time: 1441715910
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716030
#   }
#   departure {
#     time: 1441716030
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716150
#   }
#   departure {
#     time: 1441716150
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716240
#   }
#   departure {
#     time: 1441716240
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716330
#   }
#   departure {
#     time: 1441716330
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716390
#   }
#   departure {
#     time: 1441716390
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716450
#   }
#   departure {
#     time: 1441716450
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716510
#   }
#   departure {
#     time: 1441716510
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716600
#   }
#   departure {
#     time: 1441716600
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716720
#   }
#   departure {
#     time: 1441716720
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716810
#   }
#   departure {
#     time: 1441716810
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716870
#   }
#   departure {
#     time: 1441716870
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716960
#   }
#   departure {
#     time: 1441717080
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717170
#   }
#   departure {
#     time: 1441717170
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717260
#   }
#   departure {
#     time: 1441717350
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717500
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "048650_1..S"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   departure {
#     time: 1441713990
#   }
#   stop_id: "101S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714080
#   }
#   departure {
#     time: 1441714080
#   }
#   stop_id: "103S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714170
#   }
#   departure {
#     time: 1441714170
#   }
#   stop_id: "104S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714260
#   }
#   departure {
#     time: 1441714260
#   }
#   stop_id: "106S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714350
#   }
#   departure {
#     time: 1441714350
#   }
#   stop_id: "107S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714410
#   }
#   departure {
#     time: 1441714410
#   }
#   stop_id: "108S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714500
#   }
#   departure {
#     time: 1441714500
#   }
#   stop_id: "109S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714590
#   }
#   departure {
#     time: 1441714590
#   }
#   stop_id: "110S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714680
#   }
#   departure {
#     time: 1441714680
#   }
#   stop_id: "111S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714800
#   }
#   departure {
#     time: 1441714800
#   }
#   stop_id: "112S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714920
#   }
#   departure {
#     time: 1441714920
#   }
#   stop_id: "113S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715040
#   }
#   departure {
#     time: 1441715040
#   }
#   stop_id: "114S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715455
#   }
#   departure {
#     time: 1441715455
#   }
#   stop_id: "120S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715575
#   }
#   departure {
#     time: 1441715575
#   }
#   stop_id: "121S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715665
#   }
#   departure {
#     time: 1441715665
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715755
#   }
#   departure {
#     time: 1441715755
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715845
#   }
#   departure {
#     time: 1441715845
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715935
#   }
#   departure {
#     time: 1441715935
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716055
#   }
#   departure {
#     time: 1441716055
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716175
#   }
#   departure {
#     time: 1441716175
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716265
#   }
#   departure {
#     time: 1441716265
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716355
#   }
#   departure {
#     time: 1441716355
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716415
#   }
#   departure {
#     time: 1441716415
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716475
#   }
#   departure {
#     time: 1441716475
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716535
#   }
#   departure {
#     time: 1441716535
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716625
#   }
#   departure {
#     time: 1441716625
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716745
#   }
#   departure {
#     time: 1441716745
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716835
#   }
#   departure {
#     time: 1441716835
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716895
#   }
#   departure {
#     time: 1441716895
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716985
#   }
#   departure {
#     time: 1441717105
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717195
#   }
#   departure {
#     time: 1441717195
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717285
#   }
#   departure {
#     time: 1441717375
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717525
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "048950_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   departure {
#     time: 1441714170
#   }
#   stop_id: "140N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714320
#   }
#   departure {
#     time: 1441714320
#   }
#   stop_id: "139N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714380
#   }
#   departure {
#     time: 1441714380
#   }
#   stop_id: "138N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714440
#   }
#   departure {
#     time: 1441714440
#   }
#   stop_id: "137N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714500
#   }
#   departure {
#     time: 1441714500
#   }
#   stop_id: "136N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714560
#   }
#   departure {
#     time: 1441714560
#   }
#   stop_id: "135N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714680
#   }
#   departure {
#     time: 1441714680
#   }
#   stop_id: "134N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714770
#   }
#   departure {
#     time: 1441714770
#   }
#   stop_id: "133N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714860
#   }
#   departure {
#     time: 1441714860
#   }
#   stop_id: "132N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714920
#   }
#   departure {
#     time: 1441714920
#   }
#   stop_id: "131N"
# }
# stop_time_update {
#   arrival {
#     time: 1441714980
#   }
#   departure {
#     time: 1441714980
#   }
#   stop_id: "130N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715040
#   }
#   departure {
#     time: 1441715040
#   }
#   stop_id: "129N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715100
#   }
#   departure {
#     time: 1441715100
#   }
#   stop_id: "128N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715190
#   }
#   departure {
#     time: 1441715190
#   }
#   stop_id: "127N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715310
#   }
#   departure {
#     time: 1441715310
#   }
#   stop_id: "126N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715430
#   }
#   departure {
#     time: 1441715430
#   }
#   stop_id: "125N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715520
#   }
#   departure {
#     time: 1441715520
#   }
#   stop_id: "124N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715580
#   }
#   departure {
#     time: 1441715580
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715700
#   }
#   departure {
#     time: 1441715700
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715760
#   }
#   departure {
#     time: 1441715760
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715880
#   }
#   departure {
#     time: 1441715880
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1441715970
#   }
#   departure {
#     time: 1441715970
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716060
#   }
#   departure {
#     time: 1441716060
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716120
#   }
#   departure {
#     time: 1441716120
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716270
#   }
#   departure {
#     time: 1441716270
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716390
#   }
#   departure {
#     time: 1441716390
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716480
#   }
#   departure {
#     time: 1441716480
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716600
#   }
#   departure {
#     time: 1441716600
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716690
#   }
#   departure {
#     time: 1441716690
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716810
#   }
#   departure {
#     time: 1441716810
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716900
#   }
#   departure {
#     time: 1441716900
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1441716990
#   }
#   departure {
#     time: 1441716990
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717080
#   }
#   departure {
#     time: 1441717080
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717170
#   }
#   departure {
#     time: 1441717170
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717260
#   }
#   departure {
#     time: 1441717260
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717350
#   }
#   departure {
#     time: 1441717350
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717440
#   }
#   departure {
#     time: 1441717440
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717530
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "049150_1..S"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   departure {
#     time: 1441714290
#   }
#   stop_id: "101S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714380
#   }
#   departure {
#     time: 1441714380
#   }
#   stop_id: "103S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714470
#   }
#   departure {
#     time: 1441714470
#   }
#   stop_id: "104S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714560
#   }
#   departure {
#     time: 1441714560
#   }
#   stop_id: "106S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714650
#   }
#   departure {
#     time: 1441714650
#   }
#   stop_id: "107S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714710
#   }
#   departure {
#     time: 1441714710
#   }
#   stop_id: "108S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714800
#   }
#   departure {
#     time: 1441714800
#   }
#   stop_id: "109S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714890
#   }
#   departure {
#     time: 1441714890
#   }
#   stop_id: "110S"
# }
# stop_time_update {
#   arrival {
#     time: 1441714980
#   }
#   departure {
#     time: 1441714980
#   }
#   stop_id: "111S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715100
#   }
#   departure {
#     time: 1441715100
#   }
#   stop_id: "112S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715220
#   }
#   departure {
#     time: 1441715220
#   }
#   stop_id: "113S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715340
#   }
#   departure {
#     time: 1441715340
#   }
#   stop_id: "114S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715875
#   }
#   departure {
#     time: 1441715875
#   }
#   stop_id: "120S"
# }
# stop_time_update {
#   arrival {
#     time: 1441715995
#   }
#   departure {
#     time: 1441715995
#   }
#   stop_id: "121S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716085
#   }
#   departure {
#     time: 1441716085
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716175
#   }
#   departure {
#     time: 1441716175
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716265
#   }
#   departure {
#     time: 1441716265
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716355
#   }
#   departure {
#     time: 1441716355
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716475
#   }
#   departure {
#     time: 1441716475
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716595
#   }
#   departure {
#     time: 1441716595
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716685
#   }
#   departure {
#     time: 1441716685
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716775
#   }
#   departure {
#     time: 1441716775
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716835
#   }
#   departure {
#     time: 1441716835
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716895
#   }
#   departure {
#     time: 1441716895
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1441716955
#   }
#   departure {
#     time: 1441716955
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717045
#   }
#   departure {
#     time: 1441717045
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717165
#   }
#   departure {
#     time: 1441717165
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717255
#   }
#   departure {
#     time: 1441717255
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717315
#   }
#   departure {
#     time: 1441717315
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717405
#   }
#   departure {
#     time: 1441717525
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717615
#   }
#   departure {
#     time: 1441717615
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717705
#   }
#   departure {
#     time: 1441717795
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441717945
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "049950_1..S02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718698
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "050150_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718573
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "050500_1..S02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718594
#   }
#   departure {
#     time: 1441718594
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718684
#   }
#   departure {
#     time: 1441718804
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718954
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "050500_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718625
#   }
#   departure {
#     time: 1441718625
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718715
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "050850_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718666
#   }
#   departure {
#     time: 1441718666
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718756
#   }
#   departure {
#     time: 1441718756
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718846
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "051000_1..S02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718558
#   }
#   departure {
#     time: 1441718678
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718768
#   }
#   departure {
#     time: 1441718768
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718858
#   }
#   departure {
#     time: 1441718978
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719128
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "051550_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718578
#   }
#   departure {
#     time: 1441718578
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718668
#   }
#   departure {
#     time: 1441718668
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718758
#   }
#   departure {
#     time: 1441718758
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718848
#   }
#   departure {
#     time: 1441718848
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718938
#   }
#   departure {
#     time: 1441718938
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719028
#   }
#   departure {
#     time: 1441719028
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719118
#   }
#   departure {
#     time: 1441719118
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719208
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "051600_1..S02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718642
#   }
#   departure {
#     time: 1441718642
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718702
#   }
#   departure {
#     time: 1441718702
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718762
#   }
#   departure {
#     time: 1441718762
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718852
#   }
#   departure {
#     time: 1441718852
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718972
#   }
#   departure {
#     time: 1441718972
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719062
#   }
#   departure {
#     time: 1441719062
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719122
#   }
#   departure {
#     time: 1441719122
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719212
#   }
#   departure {
#     time: 1441719332
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719422
#   }
#   departure {
#     time: 1441719422
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719512
#   }
#   departure {
#     time: 1441719692
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719842
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "051900_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718626
#   }
#   departure {
#     time: 1441718626
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718746
#   }
#   departure {
#     time: 1441718746
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718836
#   }
#   departure {
#     time: 1441718836
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718926
#   }
#   departure {
#     time: 1441718926
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719016
#   }
#   departure {
#     time: 1441719016
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719106
#   }
#   departure {
#     time: 1441719106
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719196
#   }
#   departure {
#     time: 1441719196
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719286
#   }
#   departure {
#     time: 1441719286
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719376
#   }
#   departure {
#     time: 1441719406
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719496
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "052250_1..S02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718625
#   }
#   departure {
#     time: 1441718625
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718715
#   }
#   departure {
#     time: 1441718715
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718775
#   }
#   departure {
#     time: 1441718775
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718835
#   }
#   departure {
#     time: 1441718835
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718895
#   }
#   departure {
#     time: 1441718895
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718985
#   }
#   departure {
#     time: 1441718985
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719105
#   }
#   departure {
#     time: 1441719105
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719195
#   }
#   departure {
#     time: 1441719195
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719255
#   }
#   departure {
#     time: 1441719255
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719345
#   }
#   departure {
#     time: 1441719465
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719555
#   }
#   departure {
#     time: 1441719555
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719645
#   }
#   departure {
#     time: 1441719825
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719975
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "052250_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718594
#   }
#   departure {
#     time: 1441718594
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718714
#   }
#   departure {
#     time: 1441718714
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718804
#   }
#   departure {
#     time: 1441718804
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718924
#   }
#   departure {
#     time: 1441718924
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719014
#   }
#   departure {
#     time: 1441719014
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719104
#   }
#   departure {
#     time: 1441719104
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719194
#   }
#   departure {
#     time: 1441719194
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719284
#   }
#   departure {
#     time: 1441719284
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719374
#   }
#   departure {
#     time: 1441719374
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719464
#   }
#   departure {
#     time: 1441719464
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719554
#   }
#   departure {
#     time: 1441719674
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719764
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "052600_1..N09R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718609
#   }
#   departure {
#     time: 1441718609
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718729
#   }
#   departure {
#     time: 1441718729
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718819
#   }
#   departure {
#     time: 1441718819
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718939
#   }
#   departure {
#     time: 1441718939
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719029
#   }
#   departure {
#     time: 1441719029
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719149
#   }
#   departure {
#     time: 1441719149
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719239
#   }
#   departure {
#     time: 1441719239
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719329
#   }
#   departure {
#     time: 1441719329
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719419
#   }
#   departure {
#     time: 1441719419
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719479
#   }
#   stop_id: "107N"
# }
#
# trip {
#   trip_id: "052900_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718574
#   }
#   departure {
#     time: 1441718574
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718664
#   }
#   departure {
#     time: 1441718664
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718724
#   }
#   departure {
#     time: 1441718724
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718844
#   }
#   departure {
#     time: 1441718844
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718964
#   }
#   departure {
#     time: 1441718964
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719054
#   }
#   departure {
#     time: 1441719054
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719174
#   }
#   departure {
#     time: 1441719174
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719264
#   }
#   departure {
#     time: 1441719264
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719384
#   }
#   departure {
#     time: 1441719384
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719474
#   }
#   departure {
#     time: 1441719474
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719534
#   }
#   departure {
#     time: 1441719534
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719624
#   }
#   departure {
#     time: 1441719624
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719714
#   }
#   departure {
#     time: 1441719714
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719804
#   }
#   departure {
#     time: 1441719804
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719894
#   }
#   departure {
#     time: 1441719894
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719984
#   }
#   departure {
#     time: 1441719984
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720074
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "053050_1..S02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718600
#   }
#   departure {
#     time: 1441718600
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718690
#   }
#   departure {
#     time: 1441718690
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718780
#   }
#   departure {
#     time: 1441718780
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718870
#   }
#   departure {
#     time: 1441718870
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718990
#   }
#   departure {
#     time: 1441718990
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719110
#   }
#   departure {
#     time: 1441719110
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719200
#   }
#   departure {
#     time: 1441719200
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719290
#   }
#   departure {
#     time: 1441719290
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719350
#   }
#   departure {
#     time: 1441719350
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719410
#   }
#   departure {
#     time: 1441719410
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719470
#   }
#   departure {
#     time: 1441719470
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719560
#   }
#   departure {
#     time: 1441719560
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719650
#   }
#   departure {
#     time: 1441719650
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719740
#   }
#   departure {
#     time: 1441719740
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719800
#   }
#   departure {
#     time: 1441719800
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719890
#   }
#   departure {
#     time: 1441720010
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720100
#   }
#   departure {
#     time: 1441720100
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720190
#   }
#   departure {
#     time: 1441720310
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720460
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "053250_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718563
#   }
#   departure {
#     time: 1441718563
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718653
#   }
#   departure {
#     time: 1441718653
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718743
#   }
#   departure {
#     time: 1441718743
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718803
#   }
#   departure {
#     time: 1441718803
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718923
#   }
#   departure {
#     time: 1441718923
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719043
#   }
#   departure {
#     time: 1441719043
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719133
#   }
#   departure {
#     time: 1441719133
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719253
#   }
#   departure {
#     time: 1441719253
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719343
#   }
#   departure {
#     time: 1441719343
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719463
#   }
#   departure {
#     time: 1441719463
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719553
#   }
#   departure {
#     time: 1441719553
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719613
#   }
#   departure {
#     time: 1441719613
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719703
#   }
#   departure {
#     time: 1441719703
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719793
#   }
#   departure {
#     time: 1441719793
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719883
#   }
#   departure {
#     time: 1441719883
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719973
#   }
#   departure {
#     time: 1441719973
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720063
#   }
#   departure {
#     time: 1441720063
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720153
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "053350_1..S"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718697
#   }
#   departure {
#     time: 1441718697
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718787
#   }
#   departure {
#     time: 1441718787
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718847
#   }
#   departure {
#     time: 1441718847
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718937
#   }
#   departure {
#     time: 1441719057
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719147
#   }
#   departure {
#     time: 1441719147
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719237
#   }
#   departure {
#     time: 1441719357
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719507
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "053600_1..N09R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718687
#   }
#   departure {
#     time: 1441718687
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718747
#   }
#   departure {
#     time: 1441718747
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718867
#   }
#   departure {
#     time: 1441718867
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718957
#   }
#   departure {
#     time: 1441718957
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719047
#   }
#   departure {
#     time: 1441719047
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719107
#   }
#   departure {
#     time: 1441719107
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719227
#   }
#   departure {
#     time: 1441719227
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719347
#   }
#   departure {
#     time: 1441719347
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719437
#   }
#   departure {
#     time: 1441719437
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719557
#   }
#   departure {
#     time: 1441719557
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719647
#   }
#   departure {
#     time: 1441719647
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719767
#   }
#   departure {
#     time: 1441719767
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719857
#   }
#   departure {
#     time: 1441719857
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719917
#   }
#   departure {
#     time: 1441719917
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720007
#   }
#   departure {
#     time: 1441720007
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720067
#   }
#   stop_id: "107N"
# }
#
# trip {
#   trip_id: "053700_1..S02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718594
#   }
#   departure {
#     time: 1441718594
#   }
#   stop_id: "119S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718714
#   }
#   departure {
#     time: 1441718714
#   }
#   stop_id: "120S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718834
#   }
#   departure {
#     time: 1441718834
#   }
#   stop_id: "121S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718894
#   }
#   departure {
#     time: 1441718894
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718984
#   }
#   departure {
#     time: 1441718984
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719074
#   }
#   departure {
#     time: 1441719074
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719164
#   }
#   departure {
#     time: 1441719164
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719284
#   }
#   departure {
#     time: 1441719284
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719374
#   }
#   departure {
#     time: 1441719374
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719464
#   }
#   departure {
#     time: 1441719464
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719554
#   }
#   departure {
#     time: 1441719554
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719614
#   }
#   departure {
#     time: 1441719614
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719674
#   }
#   departure {
#     time: 1441719674
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719734
#   }
#   departure {
#     time: 1441719734
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719824
#   }
#   departure {
#     time: 1441719824
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719914
#   }
#   departure {
#     time: 1441719914
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720004
#   }
#   departure {
#     time: 1441720004
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720064
#   }
#   departure {
#     time: 1441720064
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720154
#   }
#   departure {
#     time: 1441720274
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720364
#   }
#   departure {
#     time: 1441720364
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720454
#   }
#   departure {
#     time: 1441720634
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720784
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "053950_1..N02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718603
#   }
#   departure {
#     time: 1441718603
#   }
#   stop_id: "124N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718663
#   }
#   departure {
#     time: 1441718663
#   }
#   stop_id: "123N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718783
#   }
#   departure {
#     time: 1441718783
#   }
#   stop_id: "122N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718843
#   }
#   departure {
#     time: 1441718843
#   }
#   stop_id: "121N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718963
#   }
#   departure {
#     time: 1441718963
#   }
#   stop_id: "120N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719053
#   }
#   departure {
#     time: 1441719053
#   }
#   stop_id: "119N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719143
#   }
#   departure {
#     time: 1441719143
#   }
#   stop_id: "118N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719203
#   }
#   departure {
#     time: 1441719203
#   }
#   stop_id: "117N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719323
#   }
#   departure {
#     time: 1441719323
#   }
#   stop_id: "116N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719443
#   }
#   departure {
#     time: 1441719443
#   }
#   stop_id: "115N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719533
#   }
#   departure {
#     time: 1441719533
#   }
#   stop_id: "114N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719653
#   }
#   departure {
#     time: 1441719653
#   }
#   stop_id: "113N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719743
#   }
#   departure {
#     time: 1441719743
#   }
#   stop_id: "112N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719863
#   }
#   departure {
#     time: 1441719863
#   }
#   stop_id: "111N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719953
#   }
#   departure {
#     time: 1441719953
#   }
#   stop_id: "110N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720013
#   }
#   departure {
#     time: 1441720013
#   }
#   stop_id: "109N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720103
#   }
#   departure {
#     time: 1441720103
#   }
#   stop_id: "108N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720193
#   }
#   departure {
#     time: 1441720193
#   }
#   stop_id: "107N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720283
#   }
#   departure {
#     time: 1441720283
#   }
#   stop_id: "106N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720373
#   }
#   departure {
#     time: 1441720373
#   }
#   stop_id: "104N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720463
#   }
#   departure {
#     time: 1441720463
#   }
#   stop_id: "103N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720553
#   }
#   stop_id: "101N"
# }
#
# trip {
#   trip_id: "054600_1..S02R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718669
#   }
#   departure {
#     time: 1441718669
#   }
#   stop_id: "114S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718759
#   }
#   departure {
#     time: 1441718849
#   }
#   stop_id: "115S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718939
#   }
#   departure {
#     time: 1441718939
#   }
#   stop_id: "116S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719089
#   }
#   departure {
#     time: 1441719089
#   }
#   stop_id: "117S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719149
#   }
#   departure {
#     time: 1441719149
#   }
#   stop_id: "118S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719209
#   }
#   departure {
#     time: 1441719209
#   }
#   stop_id: "119S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719329
#   }
#   departure {
#     time: 1441719329
#   }
#   stop_id: "120S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719449
#   }
#   departure {
#     time: 1441719449
#   }
#   stop_id: "121S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719509
#   }
#   departure {
#     time: 1441719509
#   }
#   stop_id: "122S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719599
#   }
#   departure {
#     time: 1441719599
#   }
#   stop_id: "123S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719689
#   }
#   departure {
#     time: 1441719689
#   }
#   stop_id: "124S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719779
#   }
#   departure {
#     time: 1441719779
#   }
#   stop_id: "125S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719899
#   }
#   departure {
#     time: 1441719899
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719989
#   }
#   departure {
#     time: 1441719989
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720079
#   }
#   departure {
#     time: 1441720079
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720169
#   }
#   departure {
#     time: 1441720169
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720229
#   }
#   departure {
#     time: 1441720229
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720289
#   }
#   departure {
#     time: 1441720289
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720349
#   }
#   departure {
#     time: 1441720349
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720439
#   }
#   departure {
#     time: 1441720439
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720529
#   }
#   departure {
#     time: 1441720529
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720619
#   }
#   departure {
#     time: 1441720619
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720679
#   }
#   departure {
#     time: 1441720679
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720769
#   }
#   departure {
#     time: 1441720889
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720979
#   }
#   departure {
#     time: 1441720979
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441721069
#   }
#   departure {
#     time: 1441721249
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441721399
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "054650_1..S08R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   arrival {
#     time: 1441718619
#   }
#   departure {
#     time: 1441718619
#   }
#   stop_id: "126S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718739
#   }
#   departure {
#     time: 1441718739
#   }
#   stop_id: "127S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718829
#   }
#   departure {
#     time: 1441718829
#   }
#   stop_id: "128S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718919
#   }
#   departure {
#     time: 1441718919
#   }
#   stop_id: "129S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718979
#   }
#   departure {
#     time: 1441718979
#   }
#   stop_id: "130S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719039
#   }
#   departure {
#     time: 1441719039
#   }
#   stop_id: "131S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719099
#   }
#   departure {
#     time: 1441719099
#   }
#   stop_id: "132S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719189
#   }
#   departure {
#     time: 1441719189
#   }
#   stop_id: "133S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719279
#   }
#   departure {
#     time: 1441719279
#   }
#   stop_id: "134S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719369
#   }
#   departure {
#     time: 1441719369
#   }
#   stop_id: "135S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719429
#   }
#   departure {
#     time: 1441719429
#   }
#   stop_id: "136S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719519
#   }
#   departure {
#     time: 1441719639
#   }
#   stop_id: "137S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719729
#   }
#   departure {
#     time: 1441719729
#   }
#   stop_id: "138S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719819
#   }
#   departure {
#     time: 1441719999
#   }
#   stop_id: "139S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720149
#   }
#   stop_id: "140S"
# }
#
# trip {
#   trip_id: "054650_1..N09R"
#   start_date: "20150908"
#   route_id: "1"
# }
# stop_time_update {
#   departure {
#     time: 1441717590
#   }
#   stop_id: "140N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717740
#   }
#   departure {
#     time: 1441717740
#   }
#   stop_id: "139N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717800
#   }
#   departure {
#     time: 1441717800
#   }
#   stop_id: "138N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717860
#   }
#   departure {
#     time: 1441717890
#   }
#   stop_id: "137N"
# }
# stop_time_update {
#   arrival {
#     time: 1441717950
#   }
#   departure {
#     time: 1441717950
#   }
#   stop_id: "136N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718010
#   }
#   departure {
#     time: 1441718010
#   }
#   stop_id: "135N"
# }
# stop_time_update {
#   arrival {
# ...
#     time: 1441722570
#   }
#   departure {
#     time: 1441722570
#   }
#   stop_id: "617N"
# }
# stop_time_update {
#   arrival {
#     time: 1441722690
#   }
#   departure {
#     time: 1441722690
#   }
#   stop_id: "616N"
# }
# stop_time_update {
#   arrival {
#     time: 1441722780
#   }
#   departure {
#     time: 1441722780
#   }
#   stop_id: "615N"
# }
# stop_time_update {
#   arrival {
#     time: 1441722870
#   }
#   departure {
#     time: 1441722870
#   }
#   stop_id: "614N"
# }
# stop_time_update {
#   arrival {
#     time: 1441722990
#   }
#   departure {
#     time: 1441723110
#   }
#   stop_id: "613N"
# }
# stop_time_update {
#   arrival {
#     time: 1441723440
#   }
#   stop_id: "608N"
# }
#
# trip {
#   trip_id: "050300_6..N01R"
#   start_date: "20150908"
#   route_id: "6"
# }
# stop_time_update {
#   arrival {
#     time: 1441718615
#   }
#   departure {
#     time: 1441718615
#   }
#   stop_id: "606N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718675
#   }
#   departure {
#     time: 1441718675
#   }
#   stop_id: "604N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718765
#   }
#   departure {
#     time: 1441718765
#   }
#   stop_id: "603N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718855
#   }
#   departure {
#     time: 1441718855
#   }
#   stop_id: "602N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719005
#   }
#   stop_id: "601N"
# }
#
# trip {
#   trip_id: "053300_6..N01R"
#   start_date: "20150908"
#   route_id: "6"
# }
# stop_time_update {
#   arrival {
#     time: 1441718593
#   }
#   departure {
#     time: 1441718593
#   }
#   stop_id: "623N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718683
#   }
#   departure {
#     time: 1441718683
#   }
#   stop_id: "622N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718773
#   }
#   departure {
#     time: 1441718773
#   }
#   stop_id: "621N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718953
#   }
#   departure {
#     time: 1441718953
#   }
#   stop_id: "619N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719043
#   }
#   departure {
#     time: 1441719043
#   }
#   stop_id: "618N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719103
#   }
#   departure {
#     time: 1441719103
#   }
#   stop_id: "617N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719223
#   }
#   departure {
#     time: 1441719223
#   }
#   stop_id: "616N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719313
#   }
#   departure {
#     time: 1441719313
#   }
#   stop_id: "615N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719403
#   }
#   departure {
#     time: 1441719403
#   }
#   stop_id: "614N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719523
#   }
#   departure {
#     time: 1441719523
#   }
#   stop_id: "613N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719613
#   }
#   departure {
#     time: 1441719613
#   }
#   stop_id: "612N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719703
#   }
#   departure {
#     time: 1441719703
#   }
#   stop_id: "611N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719763
#   }
#   departure {
#     time: 1441719763
#   }
#   stop_id: "610N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719853
#   }
#   departure {
#     time: 1441719853
#   }
#   stop_id: "609N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719913
#   }
#   departure {
#     time: 1441719973
#   }
#   stop_id: "608N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720063
#   }
#   departure {
#     time: 1441720063
#   }
#   stop_id: "607N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720123
#   }
#   departure {
#     time: 1441720123
#   }
#   stop_id: "606N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720183
#   }
#   departure {
#     time: 1441720183
#   }
#   stop_id: "604N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720273
#   }
#   departure {
#     time: 1441720273
#   }
#   stop_id: "603N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720363
#   }
#   departure {
#     time: 1441720363
#   }
#   stop_id: "602N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720513
#   }
#   stop_id: "601N"
# }
#
# trip {
#   trip_id: "054000_6..N06R"
#   start_date: "20150908"
#   route_id: "6"
# }
# stop_time_update {
#   arrival {
#     time: 1441718653
#   }
#   departure {
#     time: 1441718653
#   }
#   stop_id: "627N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718773
#   }
#   departure {
#     time: 1441718773
#   }
#   stop_id: "626N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718893
#   }
#   departure {
#     time: 1441718893
#   }
#   stop_id: "625N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718983
#   }
#   departure {
#     time: 1441718983
#   }
#   stop_id: "624N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719043
#   }
#   departure {
#     time: 1441719043
#   }
#   stop_id: "623N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719133
#   }
#   departure {
#     time: 1441719133
#   }
#   stop_id: "622N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719223
#   }
#   departure {
#     time: 1441719223
#   }
#   stop_id: "621N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719403
#   }
#   stop_id: "619N"
# }
#
# trip {
#   trip_id: "055550_6..S06R"
#   start_date: "20150908"
#   route_id: "6"
# }
# stop_time_update {
#   arrival {
#     time: 1441718586
#   }
#   departure {
#     time: 1441718586
#   }
#   stop_id: "623S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718676
#   }
#   departure {
#     time: 1441718676
#   }
#   stop_id: "624S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718766
#   }
#   departure {
#     time: 1441718766
#   }
#   stop_id: "625S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718886
#   }
#   departure {
#     time: 1441718886
#   }
#   stop_id: "626S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719006
#   }
#   departure {
#     time: 1441719006
#   }
#   stop_id: "627S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719126
#   }
#   departure {
#     time: 1441719126
#   }
#   stop_id: "628S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719276
#   }
#   departure {
#     time: 1441719276
#   }
#   stop_id: "629S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719396
#   }
#   departure {
#     time: 1441719396
#   }
#   stop_id: "630S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719516
#   }
#   departure {
#     time: 1441719516
#   }
#   stop_id: "631S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719636
#   }
#   departure {
#     time: 1441719636
#   }
#   stop_id: "632S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719696
#   }
#   departure {
#     time: 1441719696
#   }
#   stop_id: "633S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719756
#   }
#   departure {
#     time: 1441719756
#   }
#   stop_id: "634S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719876
#   }
#   departure {
#     time: 1441719876
#   }
#   stop_id: "635S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719966
#   }
#   departure {
#     time: 1441719966
#   }
#   stop_id: "636S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720056
#   }
#   departure {
#     time: 1441720056
#   }
#   stop_id: "637S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720116
#   }
#   departure {
#     time: 1441720116
#   }
#   stop_id: "638S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720206
#   }
#   departure {
#     time: 1441720206
#   }
#   stop_id: "639S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720326
#   }
#   stop_id: "640S"
# }
#
# trip {
#   trip_id: "056400_6..N07R"
#   start_date: "20150908"
#   route_id: "6"
# }
# stop_time_update {
#   departure {
#     time: 1441718640
#   }
#   stop_id: "640N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718760
#   }
#   departure {
#     time: 1441718760
#   }
#   stop_id: "639N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718850
#   }
#   departure {
#     time: 1441718850
#   }
#   stop_id: "638N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718910
#   }
#   departure {
#     time: 1441718910
#   }
#   stop_id: "637N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719000
#   }
#   departure {
#     time: 1441719000
#   }
#   stop_id: "636N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719090
#   }
#   departure {
#     time: 1441719090
#   }
#   stop_id: "635N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719210
#   }
#   departure {
#     time: 1441719210
#   }
#   stop_id: "634N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719270
#   }
#   departure {
#     time: 1441719270
#   }
#   stop_id: "633N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719330
#   }
#   departure {
#     time: 1441719330
#   }
#   stop_id: "632N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719450
#   }
#   departure {
#     time: 1441719450
#   }
#   stop_id: "631N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719570
#   }
#   departure {
#     time: 1441719570
#   }
#   stop_id: "630N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719660
#   }
#   departure {
#     time: 1441719660
#   }
#   stop_id: "629N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719780
#   }
#   departure {
#     time: 1441719780
#   }
#   stop_id: "628N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719870
#   }
#   departure {
#     time: 1441719870
#   }
#   stop_id: "627N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719990
#   }
#   departure {
#     time: 1441719990
#   }
#   stop_id: "626N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720110
#   }
#   departure {
#     time: 1441720110
#   }
#   stop_id: "625N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720200
#   }
#   departure {
#     time: 1441720200
#   }
#   stop_id: "624N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720260
#   }
#   departure {
#     time: 1441720260
#   }
#   stop_id: "623N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720350
#   }
#   departure {
#     time: 1441720350
#   }
#   stop_id: "622N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720440
#   }
#   departure {
#     time: 1441720440
#   }
#   stop_id: "621N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720620
#   }
#   departure {
#     time: 1441720620
#   }
#   stop_id: "619N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720710
#   }
#   departure {
#     time: 1441720710
#   }
#   stop_id: "618N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720770
#   }
#   departure {
#     time: 1441720770
#   }
#   stop_id: "617N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720890
#   }
#   departure {
#     time: 1441720890
#   }
#   stop_id: "616N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720980
#   }
#   departure {
#     time: 1441720980
#   }
#   stop_id: "615N"
# }
# stop_time_update {
#   arrival {
#     time: 1441721070
#   }
#   departure {
#     time: 1441721070
#   }
#   stop_id: "614N"
# }
# stop_time_update {
#   arrival {
#     time: 1441721190
#   }
#   departure {
#     time: 1441721280
#   }
#   stop_id: "613N"
# }
# stop_time_update {
#   arrival {
#     time: 1441721610
#   }
#   stop_id: "608N"
# }
#
# trip {
#   trip_id: "056200_GS.N01R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   arrival {
#     time: 1441718582
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "056350_GS.S04R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441718610
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718700
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "056400_GS.N03R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441718640
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718730
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "056500_GS.S01R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441718700
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718790
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "056650_GS.N04R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441718790
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718880
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "056700_GS.S03R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441718820
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441718910
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "056800_GS.N01R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441718880
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441718970
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "057000_GS.N03R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719000
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719090
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "057000_GS.S04R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719000
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719090
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "057150_GS.S01R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719090
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719180
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "057300_GS.N04R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719180
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719270
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "057350_GS.S03R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719210
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719300
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "057550_GS.N01R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719330
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719420
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "057650_GS.S04R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719390
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719480
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "057750_GS.N03R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719450
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719540
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "057900_GS.S01R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719540
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719630
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "058100_GS.N04R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719660
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719750
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "058100_GS.S03R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719660
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719750
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "058350_GS.N01R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719810
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441719900
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "058450_GS.S04R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719870
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441719960
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "058550_GS.N03R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441719930
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720020
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "058700_GS.S01R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441720020
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720110
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "058900_GS.N04R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441720140
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720230
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "058900_GS.S03R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441720140
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720230
#   }
#   stop_id: "901S"
# }
#
# trip {
#   trip_id: "059200_GS.N01R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441720320
#   }
#   stop_id: "901N"
# }
# stop_time_update {
#   arrival {
#     time: 1441720410
#   }
#   stop_id: "902N"
# }
#
# trip {
#   trip_id: "059250_GS.S04R"
#   start_date: "20150908"
#   route_id: "GS"
# }
# stop_time_update {
#   departure {
#     time: 1441720350
#   }
#   stop_id: "902S"
# }
# stop_time_update {
#   arrival {
#     time: 1441720440
#   }
#   stop_id: "901S"
# }

# %%
len(feed.entity)
# Out:
# 493

# %%
# trip ID
feed.entity[2].trip_update.trip.trip_id
# Out:
# u'045900_2..S05R'

# %%
# length of stop time update
len(feed.entity[1].trip_update.stop_time_update)
# Out:
# 0

# %%
# stop ID
feed.entity[2].trip_update.stop_time_update[0].stop_id
# Out:
# u'247S'

# %%
# time
feed.entity[2].trip_update.stop_time_update[0].arrival.time
# Out:
# 1441718609L

# %%
#system time
datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S')
# Out:
# '2015-09-08 09:26:09'

# %%
print feed.entity[2]
# Out:
# id: "000003"
# trip_update {
#   trip {
#     trip_id: "102600_1..S02R"
#     start_date: "20150722"
#     route_id: "1"
#   }
#   stop_time_update {
#     arrival {
#       time: 1437602866
#     }
#     stop_id: "140S"
#   }
# }

# %%
### save in file definition
def savefile(listitems):
    # 'a' to add line to txt file
    with open('mta.txt', 'a') as f:
            f.write(listitems + '\n')

# %%
## draft of the loop

#system time
tmpSys = datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S')

i = 1

entity=feed.entity[2]
if entity.HasField('trip_update'):
    
    ## trip update: 3 data characterisitcs
    TripIdi = entity.trip_update.trip.trip_id
    StartDatei = entity.trip_update.trip.start_date
    Routei = entity.trip_update.trip.route_id
    
    ## trip alert: 1 data characterisitcs
    if entity.HasField('alert'):
        Alerti = entity.alert.header_text
    else:
        Alerti = ''
    
    ## looking to record first 3 predicted arrival time 
    Arrivetmp=[]
    stop_id=[]
    
    tripcomplete = []
    
    if len(entity.trip_update.stop_time_update) <> 0:
        #record only first three trip updates
        p3trip = min(len(entity.trip_update.stop_time_update),3)
        
        j=0
        while j < p3trip:
            tripcomplete = []
            #print j
            ArrivalTime = entity.trip_update.stop_time_update[j].arrival.time
            stop_id = entity.trip_update.stop_time_update[j].stop_id
            
            tripcomplete.extend([tmpSys,TripIdi,StartDatei,Routei,Alerti,stop_id,ArrivalTime])
            print tripcomplete, type(tripcomplete)
            tripcomplstr = ','.join([str(i) for i in tripcomplete])
            savefile(tripcomplstr)
            
            j+=1
# Out:
# ['2015-09-08 09:26:50', u'045900_2..S05R', u'20150908', u'2', '', u'247S', 1441718609L] <type 'list'>

# %%
# Perturbation on MTA info -- webscraping of mta.info :

#definition of extracting function 

def extract_url_content(urlv, headersv):
        # Request by url and headers
        req =  requests.get(urlv, headers=headers)
        demande = req.text
        # Request status code
        statut_demande = req.status_code
        if statut_demande/100 in [4,5]:
            return 'error on requests with error: ', statut_demande
        return BeautifulSoup(demande)

# %%
# Perturbation on MTA info -- webscraping of mta.info :

#draft for the delays for different lines from mta.info

url = 'http://www.mta.info/status/subway/123'

headers = None

texturl = extract_url_content(url, headers)
print texturl.prettify
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html dir="ltr" version="XHTML+RDFa 1.0" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/terms/" xmlns:foaf="http://xmlns.com/foaf/0.1/" xmlns:og="http://ogp.me/ns#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:sioc="http://rdfs.org/sioc/ns#" xmlns:sioct="http://rdfs.org/sioc/types#" xmlns:skos="http://www.w3.org/2004/02/skos/core#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
# <head profile="http://www.w3.org/1999/xhtml/vocab">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="http://www.mta.info/sites/default/files/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed" type="image/png"/>
# <link href="http://www.mta.info/sites/default/files/apple-touch-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="http://www.mta.info/sites/all/themes/mta/images/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
# <title>MTA Service Status | MTA</title>
# <link href="http://www.mta.info/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.mta.info/sites/default/files/css/css_1BT3BPx-E-ZT0OvT0jz8a_fBsZpJCUj1DJqdI6Tr2lE.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.mta.info/sites/default/files/css/css_jxJkoHdzRdN1uuX4xCmTe-7uY81-ZptxpPdM13bF4I8.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.mta.info/sites/default/files/css/css_KmGWBphApymF3PTkHC22wkDsMo03rkga-AoKBOHGaK4.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="http://www.mta.info/sites/default/files/js/js_xAPl0qIk9eowy_iS9tNkCWXLUVoat94SQT48UBCFkyQ.js" type="text/javascript"></script>
# <script src="http://www.mta.info/sites/default/files/js/js_wVijrHU6k3obWosLX-Dc0Iu41bE7KytA82kbAjMuGmQ.js" type="text/javascript"></script>
# <script src="http://www.mta.info/sites/default/files/js/js_3Oissr0TLlayMUE1D0qb2eWdDx8Wozb8u0yAeGI145k.js" type="text/javascript"></script>
# <script src="http://translate.google.com/translate_a/element.js?cb=googleTranslateElementInit" type="text/javascript"></script>
# <script src="http://www.mta.info/sites/default/files/js/js_I8yX6RYPZb7AtMcDUA3QKDZqVkvEn35ED11_1i7vVpc.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","http://www.mta.info/sites/default/files/googleanalytics/analytics.js?nu60sx","ga");ga("create", "UA-20245417-1", {"cookieDomain":"auto"});ga("send", "pageview");
# //--><!]]>
# </script>
# <script src="http://www.mta.info/sites/default/files/js/js_K5xoxCnrq_vHutN9KzVFQGvBMf94d_vlf-Y0lyTyz-0.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"mta","theme_token":"bvHmU7ALwbwgxwC98NqC17xo20ubvrOV-YUlWLrcLCg","js":{"misc\/jquery.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/custom\/servicestatus\/servicestatus.js":1,"sites\/all\/modules\/custom\/servicestatus\/jquery.cookie.js":1,"sites\/all\/modules\/contrib\/blockcache_alter\/blockcache_alter.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/contrib\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.js":1,"http:\/\/translate.google.com\/translate_a\/element.js?cb=googleTranslateElementInit":1,"sites\/all\/modules\/contrib\/google_analytics\/googleanalytics.js":1,"0":1,"sites\/all\/libraries\/superfish\/jquery.hoverIntent.minified.js":1,"sites\/all\/libraries\/superfish\/supposition.js":1,"sites\/all\/libraries\/superfish\/jquery.bgiframe.min.js":1,"sites\/all\/libraries\/superfish\/superfish.js":1,"sites\/all\/modules\/contrib\/superfish\/superfish.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"modules\/aggregator\/aggregator.css":1,"modules\/book\/book.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/contrib\/google_appliance\/theme\/google_appliance.css":1,"modules\/node\/node.css":1,"sites\/all\/modules\/custom\/servicestatus\/service_status_style.css":1,"sites\/all\/modules\/custom\/tripplanner\/tripplanner.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/libraries\/superfish\/css\/superfish.css":1,"sites\/all\/libraries\/superfish\/style\/default.css":1,"sites\/all\/themes\/mta\/css\/global.css":1,"sites\/all\/themes\/mta\/css\/fields.css":1,"sites\/all\/themes\/mta\/css\/blocks.css":1,"sites\/all\/themes\/mta\/css\/grid.css":1,"sites\/all\/themes\/mta\/css\/mtaviews.css":1,"sites\/all\/themes\/mta\/css\/homepage.css":1,"sites\/all\/themes\/mta\/css\/topbar.css":1,"sites\/all\/themes\/mta\/css\/webform.css":1,"sites\/all\/themes\/mta\/css\/capital_style.css":1,"sites\/all\/themes\/mta\/css\/weekender.css":1}},"colorbox":{"opacity":"0.85","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","maxWidth":"98%","maxHeight":"98%","fixed":true,"mobiledetect":true,"mobiledevicewidth":"480px"},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip"},"superfish":{"1":{"id":"1","sf":{"delay":"200","animation":{"opacity":"show"},"speed":20,"autoArrows":false,"dropShadows":false,"disableHI":false},"plugins":{"supposition":true,"bgiframe":true}}}});
# //--><!]]>
# </script>
# </head>
# <body class="html not-front not-logged-in one-sidebar sidebar-second page-status page-status-subway page-status-subway- page-status-subway-123">
# <div id="skip-link">
# <a class="element-invisible element-focusable" href="#main-content">Skip to main content</a>
# </div>
# <div id="page">
# <div id="mainbox">
# <div id="topbar">
# <div id="branding">
# <a href="http://www.mta.info"><img alt="Metropolitan Transportation Authority logo" src="/sites/all/themes/mta/images/mta_info.gif"/></a>
# </div>
# <div id="middle-header">
# </div>
# <div id="search">
# <div class="region region-header-right">
# <div class="block block-menu" id="block-menu-menu-topbar-links">
# <div class="content">
# <ul class="menu"><li class="first leaf"><a href="http://web.mta.info/accessibility" title="">Accessibility</a></li>
# <li class="leaf"><a href="http://assistive.usablenet.com/tt/www.mta.info" title="">Text-only</a></li>
# <li class="leaf"><a href="http://web.mta.info/selfserve" title="">Customer Self-Service</a></li>
# <li class="leaf"><a href="http://web.mta.info/mta/employment" title="">Employment</a></li>
# <li class="last leaf"><a href="http://web.mta.info/faqs.htm" title="">FAQs/Contact Us</a></li>
# </ul> </div>
# </div>
# <div class="block block-google-appliance" id="block-google-appliance-ga-block-search-form">
# <div class="content">
# <form accept-charset="UTF-8" action="/status/subway/123" id="google-appliance-block-form" method="post"><div><div class="container-inline">
# <h2 class="element-invisible">Search Google Appliance</h2>
# <div class="form-item form-type-textfield form-item-search-keys">
# <label class="element-invisible" for="edit-search-keys">Enter the terms you wish to search for. </label>
# <input class="form-text" id="edit-search-keys" maxlength="128" name="search_keys" size="15" type="text" value=""/>
# </div>
# <div class="form-actions form-wrapper" id="edit-actions"><input class="form-submit" id="edit-submit" name="op" type="submit" value="Search"/></div><input name="form_build_id" type="hidden" value="form-NvVw-qEhmI3Pl-cTaff3Rl08SuQUNKz8KawB9EKjy_o"/>
# <input name="form_id" type="hidden" value="google_appliance_block_form"/>
# </div>
# </div></form> </div>
# </div>
# </div>
# </div>
# </div>
# <div id="navbar"> <div class="region region-navbar">
# <div class="block block-superfish" id="block-superfish-1">
# <div class="content">
# <ul class="menu sf-menu sf-main-menu sf-horizontal sf-style-default sf-total-items-8 sf-parent-items-2 sf-single-items-6" id="superfish-1"><li class="first odd sf-item-1 sf-depth-1 sf-total-children-6 sf-parent-children-0 sf-single-children-6 menuparent" id="menu-221-1"><a class="sf-depth-1 menuparent" href="http://www.mta.info" title="">Home</a><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-400-1"><a class="sf-depth-2" href="http://www.mta.info" title="">MTA Home</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-401-1"><a class="sf-depth-2" href="/nyct" title="">NYC Subways and Buses</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-402-1"><a class="sf-depth-2" href="/lirr">Long Island Rail Road</a></li><li class="middle even sf-item-4 sf-depth-2 sf-no-children" id="menu-403-1"><a class="sf-depth-2" href="/mnr">Metro-North Railroad</a></li><li class="middle odd sf-item-5 sf-depth-2 sf-no-children" id="menu-404-1"><a class="sf-depth-2" href="/bandt">Bridges and Tunnels</a></li><li class="last even sf-item-6 sf-depth-2 sf-no-children" id="menu-405-1"><a class="sf-depth-2" href="http://web.mta.info/capital" title="">MTA Capital Program</a></li></ul></li><li class="middle even sf-item-2 sf-depth-1 sf-no-children" id="menu-399-1"><a class="sf-depth-1" href="http://www.mta.info/schedules" title="">Schedules</a></li><li class="middle odd sf-item-3 sf-depth-1 sf-no-children" id="menu-414-1"><a class="sf-depth-1" href="http://web.mta.info/fares" title="">Fares &amp; Tolls</a></li><li class="middle even sf-item-4 sf-depth-1 sf-no-children" id="menu-415-1"><a class="sf-depth-1" href="http://web.mta.info/maps" title="">Maps</a></li><li class="middle odd sf-item-5 sf-depth-1 sf-no-children" id="menu-416-1"><a class="sf-depth-1" href="http://web.mta.info/service" title="">Planned Service Changes</a></li><li class="middle even sf-item-6 sf-depth-1 sf-no-children" id="menu-417-1"><a class="sf-depth-1" href="http://web.mta.info/about" title="">MTA Info</a></li><li class="middle odd sf-item-7 sf-depth-1 sf-no-children" id="menu-418-1"><a class="sf-depth-1" href="http://web.mta.info/business" title="">Doing Business With Us</a></li><li class="last even sf-item-8 sf-depth-1 sf-total-children-9 sf-parent-children-0 sf-single-children-9 menuparent" id="menu-419-1"><a class="sf-depth-1 menuparent" href="http://web.mta.info/accountability" title="">Transparency</a><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-420-1"><a class="sf-depth-2" href="http://web.mta.info/accountability" title="">Main Page</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-421-1"><a class="sf-depth-2" href="http://web.mta.info/mta/boardmaterials.html" title="">Board Materials</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-422-1"><a class="sf-depth-2" href="http://web.mta.info/mta/budget/" title="">Budget Info</a></li><li class="middle even sf-item-4 sf-depth-2 sf-no-children" id="menu-423-1"><a class="sf-depth-2" href="http://web.mta.info/capital/" title="">Capital Program Info</a></li><li class="middle odd sf-item-5 sf-depth-2 sf-no-children" id="menu-428-1"><a class="sf-depth-2" href="http://web.mta.info/capitaldashboard/CPDHome.html" title="">Capital Program Dashboard</a></li><li class="middle even sf-item-6 sf-depth-2 sf-no-children" id="menu-424-1"><a class="sf-depth-2" href="http://web.mta.info/mta/leadership/" title="">MTA Leadership</a></li><li class="middle odd sf-item-7 sf-depth-2 sf-no-children" id="menu-425-1"><a class="sf-depth-2" href="http://web.mta.info/persdashboard/performance14.html" title="">Performance Indicators</a></li><li class="middle even sf-item-8 sf-depth-2 sf-no-children" id="menu-426-1"><a class="sf-depth-2" href="/mta-news" title="">Press Releases and News</a></li><li class="last odd sf-item-9 sf-depth-2 sf-no-children" id="menu-427-1"><a class="sf-depth-2" href="http://web.mta.info/mta/new ...
# </div>
# </div>
# </div>
# <div id="breadcrumb"> <!-- we leave the div and keep spacing -->
# </div>
# <div class="container">
# <a name="main-content"></a>
# <div class="span-ad roundCorners">
# <div id="pageTitleAreaAd">
# <h1 class="title" id="page-title-ad">MTA Service Status</h1>
# </div>
# <div id="main-ad-content">
# <div class="tabs"></div> <div class="span-no-side-ad">
# <div id="status_display">The Service Status has changed. Please go back to the MTA home page for latest status.</div>
# </div>
# <!-- close span-43 -->
# </div>
# <!-- close span-21 last -->
# </div><!-- close container for grid -->
# <div class="column sidebar" id="sidebar_second_ad"><div class="section roundCorners">
# <div class="region region-sidebar-second">
# <div class="block block-google-adsense" id="block-google-adsense-google-adsense">
# <div class="content">
# <div id="Google-skyscraper-ad">
# <script type="text/javascript">
# 		<!--
# 		google_ad_client = "pub-0982027042052701";
# 		/* 160x600, created 5/6/11 */
# 		google_ad_slot = "8916589146";
# 		google_ad_width = 160;
# 		google_ad_height = 600;
#       		-->
#
#       	</script> <script src="http://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript"></script> </div> </div>
# </div>
# </div>
# </div></div> <!-- /.section, /#sidebar_second -->
# </div>
# <div id="foot-div">
# <div class="region region-footer">
# <div class="block block-google-translate" id="block-google-translate-google-translate">
# <div class="content">
# <div id="google_translate_element"></div><script>function googleTranslateElementInit() {
#   new google.translate.TranslateElement({
#     pageLanguage: 'en',
#     layout: google.translate.TranslateElement.InlineLayout.SIMPLE}, 'google_translate_element');
# }</script> </div>
# </div>
# </div>
# </div>
# </div>
# </div></body>
# </html>
# >

# %%
# Perturbation on MTA info -- webscraping of mta.info :

## draft of extraction of lines perturbated

Delaystext = texturl.find(class_="TitleDelay").get_text()
print Delaystext

lineaffected001 = texturl.findAll(id='status_display')
#print lineaffected001
lineaffected002 = [i.findAll('img') for i in lineaffected001]
print lineaffected002
print len(lineaffected002)
for j in range(len(lineaffected002)):
    textaffected001 = [i['alt'][:1] for i in lineaffected002[j]]
textaffected001

# %%
## perturbations on MTA lines are publised here:

urllist = [
    'http://www.mta.info/status/subway/123',
    'http://www.mta.info/status/subway/456',
    'http://www.mta.info/status/subway/7',
    'http://www.mta.info/status/subway/ACE',
    'http://www.mta.info/status/subway/BDFM',
    'http://www.mta.info/status/subway/JZ',
    'http://www.mta.info/status/subway/L',
    'http://www.mta.info/status/subway/NQR',
    'http://www.mta.info/status/subway/S'
]

# %%
## Summary of the loop
def listofperturbations(listOfLines):
    
    ## webscraping of mta/info using the list of url listed above
    linesperturbated = []
    for url in listOfLines:
        headers = None
        urlbody = extract_url_content(url, headers)
        #print url, 'find TitleDelay',  urlbody.find(class_="TitleDelay")
        
        if urlbody.find(class_="TitleDelay") <> None:
            Delaystext = urlbody.find(class_="TitleDelay").get_text()
            #print 'delaystext', Delaystext
            if Delaystext == "Delays":
                lineaffected001 = urlbody.findAll(id='status_display')
                lineaffected002 = [i.findAll('img') for i in lineaffected001]
                #print 'line affectd 002', lineaffected002
            for j in range(len(lineaffected002)):
                    #print j
                    for i in lineaffected002[j]:
                        try:
                            linesperturbated.extend(i['alt'][:1])
                        except:
                            continue
                            
                    #textaffected001 = [i for i in lineaffected002[j]]
                    #print textaffected001
                    #linesperturbated.extend(textaffected001)
    return linesperturbated

# %%
listofperturbations(urllist)
# Out:
# []

# %%
### save in file definition
def savefile(listitems):
    # 'a' to add line to txt file
    with open('mta.txt', 'a') as f:
            f.write(listitems + '\n')

### final code to download and clean the real time feed
def loopdwlmta(x):
    
    #system time for reference
    tmpSys = datetime.datetime.strftime(datetime.datetime.now(), '%Y-%m-%d %H:%M:%S')
    
    ##load list of lines perturbated
    listlineperturbated = listofperturbations(urllist)

    ## send request to api mta.info using my own key
    feed = gtfs_realtime_pb2.FeedMessage()
    response = urllib.urlopen('http://datamine.mta.info/mta_esi.php?key=5a8f6f4375e9f4bdea9b0c86afeaf911')
    feed.ParseFromString(response.read())
    
    
    ## looping the content downloaded
    for entity in feed.entity:
        if entity.HasField('trip_update'):
    
            ## trip update: 3 data characterisitcs
            TripIdi = entity.trip_update.trip.trip_id
            StartDatei = entity.trip_update.trip.start_date
            Routei = entity.trip_update.trip.route_id
            if Routei in listlineperturbated:
                Delaysi = "delays"
            else:
                Delaysi = ""

            ## trip alert: 1 data characterisitcs
            if entity.HasField('alert'):
                Alerti = entity.alert.header_text
            else:
                Alerti = ''

            ## looking to record first 3 predicted arrival time 
            Arrivetmp=[]
            stop_id=[]

            tripcomplete = []

            if len(entity.trip_update.stop_time_update) <> 0:
                #record only first three trip updates
                p3trip = min(len(entity.trip_update.stop_time_update),1)

                j=0
                while j < p3trip:
                    tripcomplete = []
                    #print j
                    ArrivalTime = entity.trip_update.stop_time_update[j].arrival.time
                    stop_id = entity.trip_update.stop_time_update[j].stop_id
                    station_nth=j

                    tripcomplete.extend([tmpSys,TripIdi,StartDatei,Routei,Alerti,station_nth,stop_id,ArrivalTime,Delaysi])
                    #print tripcomplete, type(tripcomplete)
                    tripcomplstr = ','.join([str(i) for i in tripcomplete])
                    savefile(tripcomplstr)

                    j+=1

# %%
# test function defined above
loopdwlmta(1)

# %%
linesperturbated = []
for url in urllist:
    headers = None
    texturl2 = extract_url_content(url, headers)
    print  texturl2.find(class_="TitleDelay") 
    if texturl2.find(class_="TitleDelay") <> None:
        Delaystext = texturl2.find(class_="TitleDelay").get_text()
        if Delaystext == "Delays":
            lineaffected001 = texturl2.findAll(id='status_display')
            lineaffected002 = [i.findAll('img') for i in lineaffected001]
            print lineaffected002
            for j in range(len(lineaffected002)):
                    #print j
                    for i in lineaffected002[j]:
                        try:
                            linesperturbated.extend(i['alt'][:1])
                        except:
                            continue
                            
                    #textaffected001 = [i for i in lineaffected002[j]]
                    #print textaffected001
                    #linesperturbated.extend(textaffected001)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
linesperturbated
# Out:
# []

# %%
import time 
while True:
    try: 
        loopdwlmta(1)
    except:
        continue
    time.sleep(300)
